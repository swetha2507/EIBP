# %% [markdown]
# # Slice Builder: GraphML Parsing
#
# This works in tandem with the Graph Analyzer code previously written, if desired (not required). That code can be found here: https://github.com/pjw7904/Graph-Analyzer/tree/develop
#
# Any graphml file comprised of basic node and edge tags will be able to work with this parser. Each node will be set up as a FABRIC node and any edge will be set up as a l2network between the specified nodes. Currently, this code does not consider extended LANs with more than two nodes.
#
# This was written to take advantage of existing graphml files, as opposed to the FABRIC-enhanced graphml RSPEC files that contain hardware properties that go beyond the basic topological information.

# %% [markdown]
# ## Input Required Information
#
# | Variable | Use |
# | --- | --- |
# | SLICE_NAME    | Name of slice you want to create. Please make sure a slice with that name does not already exist. |
# | SITE_NAME     | Name of the FABRIC site you want the nodes to be reserved at. This code does not consider inter-site situations, the entire topology is reserved on a single slice. |
# | GRAPH_PATH    | Path to the graphml file you want to use to create a topology. |
# | HAS_CLIENTS   | Enter True if clients are present in topology, if not, False. These nodes and the networks connecting them utilizes alternative naming and addressing structures. |
# | CLIENT_PREFIX | The naming prefix given to each node (currently, this is required if the topology does have clients) |

# %%
SLICE_NAME = "EIBP_1"
SITE_NAME = "MASS"
GRAPH_PATH = "/home/fabric/work/NShenoy/EIBP_23/graph/eibp_small.graphml"
HAS_CLIENTS = True
CLIENT_PREFIX = "ipnode" #ipnode name

# %% [markdown]
# ## Import the FABlib Library and Confirm the Configuration is Correct

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

try:
    fablib = fablib_manager()

    fablib.show_config()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_4f386 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_4f386 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4f386 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_4f386_row0_col0, #T_4f386_row0_col1, #T_4f386_row1_col0, #T_4f386_row1_col1, #T_4f386_row2_col0, #T_4f386_row2_col1, #T_4f386_row3_col0, #T_4f386_row3_col1, #T_4f386_row4_col0, #T_4f386_row4_col1, #T_4f386_row5_col0, #T_4f386_row5_col1, #T_4f386_row6_col0, #T_4f386_row6_col1, #T_4f386_row7_col0, #T_4f386_row7_col1, #T_4f386_row8_col0, #T_4f386_row8_col1, #T_4f386_row9_col0, #T_4f386_row9_col1, #T_4f386_row10_col0, #T_4f386_row10_col1, #T_4f386_row11_col0, #T_4f386_row11_col1, #T_4f386_row12_col0, #T_4f386_row12_col1, #T_4f386_row13_col0, #T_4f386_row13_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_4f386">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4f386_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_4f386_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_4f386_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_4f386_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_4f386_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_4f386_row2_col1" class="data row2 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_4f386_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_4f386_row3_col1" class="data row3 col1" >787adfc9-d37e-42f2-8efe-8e32793e0bb8</td>
#     </tr>
#     <tr>
#       <td id="T_4f386_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_4f386_row4_col1" class="data row4 col1" >nxsvks_0000031803</td>
#     </tr>
#     <tr>
#       <td id="T_4f386_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_4f386_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/B_trying</td>
#     </tr>
#     <tr>
#       <td id="T_4f386_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_4f386_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_4f386_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_4f386_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_4f386_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_4f386_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/trying.pub</td>
#     </tr>
#     <tr>
#       <td id="T_4f386_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_4f386_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/trying</td>
#     </tr>
#     <tr>
#       <td id="T_4f386_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_4f386_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_4f386_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_4f386_row11_col1" class="data row11 col1" >/home/fabric/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_4f386_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_4f386_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_4f386_row13_col0" class="data row13 col0" >Version</td>
#       <td id="T_4f386_row13_col1" class="data row13 col1" >1.5.4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Parse GraphML for Topology and Create Slice
#
# The minidom library is used to parse the graphml. It assumes proper use of the node and edge tags. Examples of valid tags can be seen below. The name of the node is the node's id. Furthermore, it does not matter which node is the source and destination, it is parsed as an undirected graph and there will be issues if you try and create another network between the same two nodes.
#
#     <node id="c" />
#     <node id="d" />
#     <node id ="a" />
#     <edge source="c1" target="d1" />

# %%
import xml.dom.minidom
from collections import Counter

STARTING_INTF_NUM = 1

try:
    #Create the slice
    slice = fablib.new_slice(name=SLICE_NAME)

    # Create dictionary to store nodes
    nodeDict = {}

    # Use XML parser to parse the GraphML file
    docs = xml.dom.minidom.parse(GRAPH_PATH)

    # Find all nodes via the node tag, add each to the slice with Rocky Linux as its base
    nodes = docs.getElementsByTagName("node")
    for node in nodes:
        # Grab the node name and determine if it is a client node based on its name prefix
        nodeName = node.getAttribute("id")
        isClient = True if HAS_CLIENTS and nodeName.startswith(CLIENT_PREFIX) else False # Check for compute/client nodes

        # Add node to the slice
        nodeInfo = slice.add_node(name=nodeName, cores=1, ram=4, image='default_rocky_8', site=SITE_NAME)

        # nodeDict = 0 -> FABRIC node object, 1 -> current intf number, 2 -> is a client/server (True) or not (False)
        nodeDict[nodeName] = {"nodeInfo": nodeInfo, "currentIntfNum": STARTING_INTF_NUM, "isClient": isClient}
        #[nodeInfo, 1, isClient]

        print(f'Added node {nodeName}')



    # Find all edges via the edge tag, add each to the slice via an L2Bridge connecting the node interfaces
    edges = docs.getElementsByTagName("edge")
    for edge in edges:
        # grab nodes x and y in edge (x,y)
        source = edge.getAttribute("source")
        target = edge.getAttribute("target")

        # Create an interface name for each interface in the network
        sourceIntfName = "eth{num}".format(node=source, num=nodeDict[source]["currentIntfNum"])
        targetIntfName = "eth{num}".format(node=target, num=nodeDict[target]["currentIntfNum"])

        # Name a network based on if it is a user-facing LAN (edge) or P2P links in the core of the network (core)
        networkPrefix = "edge" if nodeDict[source]["isClient"]  or nodeDict[target]["isClient"] else "core"
        networkName = f'{networkPrefix}-{source}-{target}'

        # Add a NIC for each node that is a part of the edge
        sourceIntf = nodeDict[source]["nodeInfo"].add_component(model='NIC_Basic', name=sourceIntfName).get_interfaces()[0]
        targetIntf = nodeDict[target]["nodeInfo"].add_component(model='NIC_Basic', name=targetIntfName).get_interfaces()[0]

        nodeDict[source]["currentIntfNum"] += 1
        nodeDict[target]["currentIntfNum"] += 1

        # Add a L2 network between the interfaces
        slice.add_l2network(name=networkName, interfaces=[sourceIntf, targetIntf], type="L2Bridge")

        print(f'Added edge {source}-{target}')


    #Submit Slice Request
    slice.submit()


except Exception as e:
    print(f"Exception: {e}")
# Out:
# Retry: 10, Time: 592 sec
# <style type="text/css">
# #T_ceb7d tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_ceb7d tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_ceb7d caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_ceb7d_row0_col0, #T_ceb7d_row0_col1, #T_ceb7d_row1_col0, #T_ceb7d_row1_col1, #T_ceb7d_row2_col0, #T_ceb7d_row2_col1, #T_ceb7d_row3_col0, #T_ceb7d_row3_col1, #T_ceb7d_row4_col0, #T_ceb7d_row4_col1, #T_ceb7d_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_ceb7d_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_ceb7d">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ceb7d_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_ceb7d_row0_col1" class="data row0 col1" >5db78376-07f5-4eb8-b1e3-52266880eb4a</td>
#     </tr>
#     <tr>
#       <td id="T_ceb7d_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_ceb7d_row1_col1" class="data row1 col1" >EIBP_1</td>
#     </tr>
#     <tr>
#       <td id="T_ceb7d_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_ceb7d_row2_col1" class="data row2 col1" >2023-12-01 15:00:33 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_ceb7d_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_ceb7d_row3_col1" class="data row3 col1" >2023-11-30 15:00:34 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_ceb7d_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_ceb7d_row4_col1" class="data row4 col1" >787adfc9-d37e-42f2-8efe-8e32793e0bb8</td>
#     </tr>
#     <tr>
#       <td id="T_ceb7d_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_ceb7d_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0aab8 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_0aab8 th {
#   text-align: left;
# }
# #T_0aab8 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0aab8 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_0aab8 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0aab8_row0_col0, #T_0aab8_row0_col1, #T_0aab8_row0_col2, #T_0aab8_row0_col3, #T_0aab8_row0_col4, #T_0aab8_row0_col5, #T_0aab8_row0_col6, #T_0aab8_row0_col7, #T_0aab8_row0_col8, #T_0aab8_row0_col9, #T_0aab8_row0_col10, #T_0aab8_row0_col13, #T_0aab8_row0_col14, #T_0aab8_row0_col15, #T_0aab8_row1_col0, #T_0aab8_row1_col1, #T_0aab8_row1_col2, #T_0aab8_row1_col3, #T_0aab8_row1_col4, #T_0aab8_row1_col5, #T_0aab8_row1_col6, #T_0aab8_row1_col7, #T_0aab8_row1_col8, #T_0aab8_row1_col9, #T_0aab8_row1_col10, #T_0aab8_row1_col13, #T_0aab8_row1_col14, #T_0aab8_row1_col15, #T_0aab8_row2_col0, #T_0aab8_row2_col1, #T_0aab8_row2_col2, #T_0aab8_row2_col3, #T_0aab8_row2_col4, #T_0aab8_row2_col5, #T_0aab8_row2_col6, #T_0aab8_row2_col7, #T_0aab8_row2_col8, #T_0aab8_row2_col9, #T_0aab8_row2_col10, #T_0aab8_row2_col13, #T_0aab8_row2_col14, #T_0aab8_row2_col15, #T_0aab8_row3_col0, #T_0aab8_row3_col1, #T_0aab8_row3_col2, #T_0aab8_row3_col3, #T_0aab8_row3_col4, #T_0aab8_row3_col5, #T_0aab8_row3_col6, #T_0aab8_row3_col7, #T_0aab8_row3_col8, #T_0aab8_row3_col9, #T_0aab8_row3_col10, #T_0aab8_row3_col13, #T_0aab8_row3_col14, #T_0aab8_row3_col15, #T_0aab8_row4_col0, #T_0aab8_row4_col1, #T_0aab8_row4_col2, #T_0aab8_row4_col3, #T_0aab8_row4_col4, #T_0aab8_row4_col5, #T_0aab8_row4_col6, #T_0aab8_row4_col7, #T_0aab8_row4_col8, #T_0aab8_row4_col9, #T_0aab8_row4_col10, #T_0aab8_row4_col13, #T_0aab8_row4_col14, #T_0aab8_row4_col15, #T_0aab8_row5_col0, #T_0aab8_row5_col1, #T_0aab8_row5_col2, #T_0aab8_row5_col3, #T_0aab8_row5_col4, #T_0aab8_row5_col5, #T_0aab8_row5_col6, #T_0aab8_row5_col7, #T_0aab8_row5_col8, #T_0aab8_row5_col9, #T_0aab8_row5_col10, #T_0aab8_row5_col13, #T_0aab8_row5_col14, #T_0aab8_row5_col15, #T_0aab8_row6_col0, #T_0aab8_row6_col1, #T_0aab8_row6_col2, #T_0aab8_row6_col3, #T_0aab8_row6_col4, #T_0aab8_row6_col5, #T_0aab8_row6_col6, #T_0aab8_row6_col7, #T_0aab8_row6_col8, #T_0aab8_row6_col9, #T_0aab8_row6_col10, #T_0aab8_row6_col13, #T_0aab8_row6_col14, #T_0aab8_row6_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_0aab8_row0_col11, #T_0aab8_row1_col11, #T_0aab8_row2_col11, #T_0aab8_row3_col11, #T_0aab8_row4_col11, #T_0aab8_row5_col11, #T_0aab8_row6_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_0aab8_row0_col12, #T_0aab8_row1_col12, #T_0aab8_row2_col12, #T_0aab8_row3_col12, #T_0aab8_row4_col12, #T_0aab8_row5_col12, #T_0aab8_row6_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_0aab8">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_0aab8_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_0aab8_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_0aab8_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_0aab8_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_0aab8_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_0aab8_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_0aab8_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_0aab8_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_0aab8_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_0aab8_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_0aab8_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_0aab8_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_0aab8_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_0aab8_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_0aab8_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_0aab8_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0aab8_row0_col0" class="data row0 col0" >1094f626-3eac-41c2-9f7e-4a82425defcc</td>
#       <td id="T_0aab8_row0_col1" class="data row0 col1" >a1</td>
#       <td id="T_0aab8_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_0aab8_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_0aab8_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_0aab8_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_0aab8_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_0aab8_row0_col7" class="data row0 col7" >mass-w1.fabric-testbed.net</td>
#       <td id="T_0aab8_row0_col8" class="data row0 col8" >MASS</td>
#       <td id="T_0aab8_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_0aab8_row0_col10" class="data row0 col10" >205.172.170.105</td>
#       <td id="T_0aab8_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_0aab8_row0_col12" class="data row0 col12" ></td>
#       <td id="T_0aab8_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/trying -F /home/fabric/work/fabric_config/ssh_config rocky@205.172.170.105</td>
#       <td id="T_0aab8_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/trying.pub</td>
#       <td id="T_0aab8_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/trying</td>
#     </tr>
#     <tr>
#       <td id="T_0aab8_row1_col0" class="data row1 col0" >57d46dc7-8f72-477f-89f0-32fe16e20329</td>
#       <td id="T_0aab8_row1_col1" class="data row1 col1" >a2</td>
#       <td id="T_0aab8_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_0aab8_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_0aab8_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_0aab8_row1_col5" class="data row1 col5" >default_rocky_8</td>
#       <td id="T_0aab8_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_0aab8_row1_col7" class="data row1 col7" >mass-w1.fabric-testbed.net</td>
#       <td id="T_0aab8_row1_col8" class="data row1 col8" >MASS</td>
#       <td id="T_0aab8_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_0aab8_row1_col10" class="data row1 col10" >205.172.170.88</td>
#       <td id="T_0aab8_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_0aab8_row1_col12" class="data row1 col12" ></td>
#       <td id="T_0aab8_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/trying -F /home/fabric/work/fabric_config/ssh_config rocky@205.172.170.88</td>
#       <td id="T_0aab8_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/trying.pub</td>
#       <td id="T_0aab8_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/trying</td>
#     </tr>
#     <tr>
#       <td id="T_0aab8_row2_col0" class="data row2 col0" >d963627b-3b18-4413-972c-9a59b6198098</td>
#       <td id="T_0aab8_row2_col1" class="data row2 col1" >c1</td>
#       <td id="T_0aab8_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_0aab8_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_0aab8_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_0aab8_row2_col5" class="data row2 col5" >default_rocky_8</td>
#       <td id="T_0aab8_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_0aab8_row2_col7" class="data row2 col7" >mass-w1.fabric-testbed.net</td>
#       <td id="T_0aab8_row2_col8" class="data row2 col8" >MASS</td>
#       <td id="T_0aab8_row2_col9" class="data row2 col9" >rocky</td>
#       <td id="T_0aab8_row2_col10" class="data row2 col10" >205.172.170.122</td>
#       <td id="T_0aab8_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_0aab
# <style type="text/css">
# #T_2dd0e caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_2dd0e th {
#   text-align: left;
# }
# #T_2dd0e tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_2dd0e tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_2dd0e .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_2dd0e_row0_col0, #T_2dd0e_row0_col1, #T_2dd0e_row0_col2, #T_2dd0e_row0_col3, #T_2dd0e_row0_col4, #T_2dd0e_row0_col5, #T_2dd0e_row0_col6, #T_2dd0e_row1_col0, #T_2dd0e_row1_col1, #T_2dd0e_row1_col2, #T_2dd0e_row1_col3, #T_2dd0e_row1_col4, #T_2dd0e_row1_col5, #T_2dd0e_row1_col6, #T_2dd0e_row2_col0, #T_2dd0e_row2_col1, #T_2dd0e_row2_col2, #T_2dd0e_row2_col3, #T_2dd0e_row2_col4, #T_2dd0e_row2_col5, #T_2dd0e_row2_col6, #T_2dd0e_row3_col0, #T_2dd0e_row3_col1, #T_2dd0e_row3_col2, #T_2dd0e_row3_col3, #T_2dd0e_row3_col4, #T_2dd0e_row3_col5, #T_2dd0e_row3_col6, #T_2dd0e_row4_col0, #T_2dd0e_row4_col1, #T_2dd0e_row4_col2, #T_2dd0e_row4_col3, #T_2dd0e_row4_col4, #T_2dd0e_row4_col5, #T_2dd0e_row4_col6, #T_2dd0e_row5_col0, #T_2dd0e_row5_col1, #T_2dd0e_row5_col2, #T_2dd0e_row5_col3, #T_2dd0e_row5_col4, #T_2dd0e_row5_col5, #T_2dd0e_row5_col6, #T_2dd0e_row6_col0, #T_2dd0e_row6_col1, #T_2dd0e_row6_col2, #T_2dd0e_row6_col3, #T_2dd0e_row6_col4, #T_2dd0e_row6_col5, #T_2dd0e_row6_col6, #T_2dd0e_row7_col0, #T_2dd0e_row7_col1, #T_2dd0e_row7_col2, #T_2dd0e_row7_col3, #T_2dd0e_row7_col4, #T_2dd0e_row7_col5, #T_2dd0e_row7_col6, #T_2dd0e_row8_col0, #T_2dd0e_row8_col1, #T_2dd0e_row8_col2, #T_2dd0e_row8_col3, #T_2dd0e_row8_col4, #T_2dd0e_row8_col5, #T_2dd0e_row8_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_2dd0e_row0_col7, #T_2dd0e_row1_col7, #T_2dd0e_row2_col7, #T_2dd0e_row3_col7, #T_2dd0e_row4_col7, #T_2dd0e_row5_col7, #T_2dd0e_row6_col7, #T_2dd0e_row7_col7, #T_2dd0e_row8_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_2dd0e_row0_col8, #T_2dd0e_row1_col8, #T_2dd0e_row2_col8, #T_2dd0e_row3_col8, #T_2dd0e_row4_col8, #T_2dd0e_row5_col8, #T_2dd0e_row6_col8, #T_2dd0e_row7_col8, #T_2dd0e_row8_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_2dd0e">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_2dd0e_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_2dd0e_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_2dd0e_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_2dd0e_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_2dd0e_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_2dd0e_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_2dd0e_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_2dd0e_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_2dd0e_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2dd0e_row0_col0" class="data row0 col0" >5fcb0d02-275f-4d6d-9236-cc849b3c08a2</td>
#       <td id="T_2dd0e_row0_col1" class="data row0 col1" >core-a1-d1</td>
#       <td id="T_2dd0e_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_2dd0e_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_2dd0e_row0_col4" class="data row0 col4" >MASS</td>
#       <td id="T_2dd0e_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_2dd0e_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_2dd0e_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_2dd0e_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_2dd0e_row1_col0" class="data row1 col0" >4cda9266-ce47-439d-a6b7-85e7e88ec852</td>
#       <td id="T_2dd0e_row1_col1" class="data row1 col1" >core-a1-d2</td>
#       <td id="T_2dd0e_row1_col2" class="data row1 col2" >L2</td>
#       <td id="T_2dd0e_row1_col3" class="data row1 col3" >L2Bridge</td>
#       <td id="T_2dd0e_row1_col4" class="data row1 col4" >MASS</td>
#       <td id="T_2dd0e_row1_col5" class="data row1 col5" >None</td>
#       <td id="T_2dd0e_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_2dd0e_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_2dd0e_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_2dd0e_row2_col0" class="data row2 col0" >ea041582-7d64-4491-b694-d5873c6e30dd</td>
#       <td id="T_2dd0e_row2_col1" class="data row2 col1" >core-c1-d1</td>
#       <td id="T_2dd0e_row2_col2" class="data row2 col2" >L2</td>
#       <td id="T_2dd0e_row2_col3" class="data row2 col3" >L2Bridge</td>
#       <td id="T_2dd0e_row2_col4" class="data row2 col4" >MASS</td>
#       <td id="T_2dd0e_row2_col5" class="data row2 col5" >None</td>
#       <td id="T_2dd0e_row2_col6" class="data row2 col6" >None</td>
#       <td id="T_2dd0e_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T_2dd0e_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_2dd0e_row3_col0" class="data row3 col0" >f1451334-eb7b-478f-bf37-f30ac097c44b</td>
#       <td id="T_2dd0e_row3_col1" class="data row3 col1" >core-c1-d2</td>
#       <td id="T_2dd0e_row3_col2" class="data row3 col2" >L2</td>
#       <td id="T_2dd0e_row3_col3" class="data row3 col3" >L2Bridge</td>
#       <td id="T_2dd0e_row3_col4" class="data row3 col4" >MASS</td>
#       <td id="T_2dd0e_row3_col5" class="data row3 col5" >None</td>
#       <td id="T_2dd0e_row3_col6" class="data row3 col6" >None</td>
#       <td id="T_2dd0e_row3_col7" class="data row3 col7" >Active</td>
#       <td id="T_2dd0e_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_2dd0e_row4_col0" class="data row4 col0" >966916af-e20a-4d02-94b3-aae25147a495</td>
#       <td id="T_2dd0e_row4_col1" class="data row4 col1" >core-d1-a2</td>
#       <td id="T_2dd0e_row4_col2" class="data row4 col2" >L2</td>
#       <td id="T_2dd0e_row4_col3" class="data row4 col3" >L2Bridge</td>
#       <td id="T_2dd0e_row4_col4" class="data row4 col4" >MASS</td>
#       <td id="T_2dd0e_row4_col5" class="data row4 col5" >None</td>
#       <td id="T_2dd0e_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_2dd0e_row4_col7" class="data row4 col7" >Active</td>
#       <td id="T_2dd0e_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_2dd0e_row5_col0" class="data row5 col0" >4a14c4bb-6c8c-4c2a-86ba-b113153059f8</td>
#       <td id="T_2dd0e_row5_col1" class="data row5 col1" >core-d2-a2</td>
#       <td id="T_2dd0e_row5_col2" class="data row5 col2" >L2</td>
#       <td id="T_2dd0e_row5_col3" class="data row5 col3" >L2Bridge</td>
#       <td id="T_2dd0e_row5_col4" class="data row5 col4" >MASS</td>
#       <td id="T_2dd0e_row5_col5" class="data row5 col5" >None</td>
#       <td id="T_2dd0e_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_2dd0e_row5_col7" class="data row5 col7" >Active</td>
#       <td id="T_2dd0e_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_2dd0e_row6_col0" class="data row6 col0" >885bd08a-b9f6-480f-a6dd-d899cc6fc6f2</td>
#       <td id="T_2dd0e_row6_col1" class="data row6 col1" >core-d2-d1</td>
#       <td id="T_2dd0e_row6_col2" class="data row6 col2" >L2</td>
#       <td id="T_2dd0e_row6_col3" class="data row6 col3" >L2Bridge</td>
#       <td id="T_2dd0e_row6_col4" class="data row6 col4" >MASS</td>
#       <td id="T_2dd0e_row6_col5" class="data row6 col5" >None</td>
#       <td id="T_2dd0e_row6_col6" class="data row6 col6" >None</td>
#       <td id="T_2dd0e_row6_col7" class="data row6 col7" >Active</td>
#       <td id="T_2dd0e_row6_col8" class="data row6 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_2dd0e_row7_col0" class="data row7 col0" >d0935f56-9b0c-4510-8b97-6f24c91759f9</td>
#       <td id="T_2dd0e_row7_col1" class="data row7 col1" >edge-a1-ipnode-1</td>
#       <td id="T_2dd0e_row7_col2" class="data row7 col2" >L2</td>
# <style type="text/css">
# #T_1ba0e caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_1ba0e th {
#   text-align: left;
# }
# #T_1ba0e tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_1ba0e tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_1ba0e .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_1ba0e_row0_col0, #T_1ba0e_row0_col1, #T_1ba0e_row0_col2, #T_1ba0e_row0_col3, #T_1ba0e_row0_col4, #T_1ba0e_row0_col5, #T_1ba0e_row0_col6, #T_1ba0e_row0_col7, #T_1ba0e_row0_col8, #T_1ba0e_row0_col9, #T_1ba0e_row0_col10, #T_1ba0e_row0_col11, #T_1ba0e_row1_col0, #T_1ba0e_row1_col1, #T_1ba0e_row1_col2, #T_1ba0e_row1_col3, #T_1ba0e_row1_col4, #T_1ba0e_row1_col5, #T_1ba0e_row1_col6, #T_1ba0e_row1_col7, #T_1ba0e_row1_col8, #T_1ba0e_row1_col9, #T_1ba0e_row1_col10, #T_1ba0e_row1_col11, #T_1ba0e_row2_col0, #T_1ba0e_row2_col1, #T_1ba0e_row2_col2, #T_1ba0e_row2_col3, #T_1ba0e_row2_col4, #T_1ba0e_row2_col5, #T_1ba0e_row2_col6, #T_1ba0e_row2_col7, #T_1ba0e_row2_col8, #T_1ba0e_row2_col9, #T_1ba0e_row2_col10, #T_1ba0e_row2_col11, #T_1ba0e_row3_col0, #T_1ba0e_row3_col1, #T_1ba0e_row3_col2, #T_1ba0e_row3_col3, #T_1ba0e_row3_col4, #T_1ba0e_row3_col5, #T_1ba0e_row3_col6, #T_1ba0e_row3_col7, #T_1ba0e_row3_col8, #T_1ba0e_row3_col9, #T_1ba0e_row3_col10, #T_1ba0e_row3_col11, #T_1ba0e_row4_col0, #T_1ba0e_row4_col1, #T_1ba0e_row4_col2, #T_1ba0e_row4_col3, #T_1ba0e_row4_col4, #T_1ba0e_row4_col5, #T_1ba0e_row4_col6, #T_1ba0e_row4_col7, #T_1ba0e_row4_col8, #T_1ba0e_row4_col9, #T_1ba0e_row4_col10, #T_1ba0e_row4_col11, #T_1ba0e_row5_col0, #T_1ba0e_row5_col1, #T_1ba0e_row5_col2, #T_1ba0e_row5_col3, #T_1ba0e_row5_col4, #T_1ba0e_row5_col5, #T_1ba0e_row5_col6, #T_1ba0e_row5_col7, #T_1ba0e_row5_col8, #T_1ba0e_row5_col9, #T_1ba0e_row5_col10, #T_1ba0e_row5_col11, #T_1ba0e_row6_col0, #T_1ba0e_row6_col1, #T_1ba0e_row6_col2, #T_1ba0e_row6_col3, #T_1ba0e_row6_col4, #T_1ba0e_row6_col5, #T_1ba0e_row6_col6, #T_1ba0e_row6_col7, #T_1ba0e_row6_col8, #T_1ba0e_row6_col9, #T_1ba0e_row6_col10, #T_1ba0e_row6_col11, #T_1ba0e_row7_col0, #T_1ba0e_row7_col1, #T_1ba0e_row7_col2, #T_1ba0e_row7_col3, #T_1ba0e_row7_col4, #T_1ba0e_row7_col5, #T_1ba0e_row7_col6, #T_1ba0e_row7_col7, #T_1ba0e_row7_col8, #T_1ba0e_row7_col9, #T_1ba0e_row7_col10, #T_1ba0e_row7_col11, #T_1ba0e_row8_col0, #T_1ba0e_row8_col1, #T_1ba0e_row8_col2, #T_1ba0e_row8_col3, #T_1ba0e_row8_col4, #T_1ba0e_row8_col5, #T_1ba0e_row8_col6, #T_1ba0e_row8_col7, #T_1ba0e_row8_col8, #T_1ba0e_row8_col9, #T_1ba0e_row8_col10, #T_1ba0e_row8_col11, #T_1ba0e_row9_col0, #T_1ba0e_row9_col1, #T_1ba0e_row9_col2, #T_1ba0e_row9_col3, #T_1ba0e_row9_col4, #T_1ba0e_row9_col5, #T_1ba0e_row9_col6, #T_1ba0e_row9_col7, #T_1ba0e_row9_col8, #T_1ba0e_row9_col9, #T_1ba0e_row9_col10, #T_1ba0e_row9_col11, #T_1ba0e_row10_col0, #T_1ba0e_row10_col1, #T_1ba0e_row10_col2, #T_1ba0e_row10_col3, #T_1ba0e_row10_col4, #T_1ba0e_row10_col5, #T_1ba0e_row10_col6, #T_1ba0e_row10_col7, #T_1ba0e_row10_col8, #T_1ba0e_row10_col9, #T_1ba0e_row10_col10, #T_1ba0e_row10_col11, #T_1ba0e_row11_col0, #T_1ba0e_row11_col1, #T_1ba0e_row11_col2, #T_1ba0e_row11_col3, #T_1ba0e_row11_col4, #T_1ba0e_row11_col5, #T_1ba0e_row11_col6, #T_1ba0e_row11_col7, #T_1ba0e_row11_col8, #T_1ba0e_row11_col9, #T_1ba0e_row11_col10, #T_1ba0e_row11_col11, #T_1ba0e_row12_col0, #T_1ba0e_row12_col1, #T_1ba0e_row12_col2, #T_1ba0e_row12_col3, #T_1ba0e_row12_col4, #T_1ba0e_row12_col5, #T_1ba0e_row12_col6, #T_1ba0e_row12_col7, #T_1ba0e_row12_col8, #T_1ba0e_row12_col9, #T_1ba0e_row12_col10, #T_1ba0e_row12_col11, #T_1ba0e_row13_col0, #T_1ba0e_row13_col1, #T_1ba0e_row13_col2, #T_1ba0e_row13_col3, #T_1ba0e_row13_col4, #T_1ba0e_row13_col5, #T_1ba0e_row13_col6, #T_1ba0e_row13_col7, #T_1ba0e_row13_col8, #T_1ba0e_row13_col9, #T_1ba0e_row13_col10, #T_1ba0e_row13_col11, #T_1ba0e_row14_col0, #T_1ba0e_row14_col1, #T_1ba0e_row14_col2, #T_1ba0e_row14_col3, #T_1ba0e_row14_col4, #T_1ba0e_row14_col5, #T_1ba0e_row14_col6, #T_1ba0e_row14_col7, #T_1ba0e_row14_col8, #T_1ba0e_row14_col9, #T_1ba0e_row14_col10, #T_1ba0e_row14_col11, #T_1ba0e_row15_col0, #T_1ba0e_row15_col1, #T_1ba0e_row15_col2, #T_1ba0e_row15_col3, #T_1ba0e_row15_col4, #T_1ba0e_row15_col5, #T_1ba0e_row15_col6, #T_1ba0e_row15_col7, #T_1ba0e_row15_col8, #T_1ba0e_row15_col9, #T_1ba0e_row15_col10, #T_1ba0e_row15_col11, #T_1ba0e_row16_col0, #T_1ba0e_row16_col1, #T_1ba0e_row16 ...
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_1ba0e">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_1ba0e_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_1ba0e_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_1ba0e_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_1ba0e_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_1ba0e_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_1ba0e_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_1ba0e_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_1ba0e_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_1ba0e_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_1ba0e_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_1ba0e_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_1ba0e_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1ba0e_row0_col0" class="data row0 col0" >c1-eth2-p1</td>
#       <td id="T_1ba0e_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_1ba0e_row0_col2" class="data row0 col2" >c1</td>
#       <td id="T_1ba0e_row0_col3" class="data row0 col3" >core-c1-d1</td>
#       <td id="T_1ba0e_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_1ba0e_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_1ba0e_row0_col6" class="data row0 col6" ></td>
#       <td id="T_1ba0e_row0_col7" class="data row0 col7" >02:69:DD:00:D4:CE</td>
#       <td id="T_1ba0e_row0_col8" class="data row0 col8" >eth1</td>
#       <td id="T_1ba0e_row0_col9" class="data row0 col9" >eth1</td>
#       <td id="T_1ba0e_row0_col10" class="data row0 col10" >None</td>
#       <td id="T_1ba0e_row0_col11" class="data row0 col11" >6</td>
#     </tr>
#     <tr>
#       <td id="T_1ba0e_row1_col0" class="data row1 col0" >c1-eth1-p1</td>
#       <td id="T_1ba0e_row1_col1" class="data row1 col1" >p1</td>
#       <td id="T_1ba0e_row1_col2" class="data row1 col2" >c1</td>
#       <td id="T_1ba0e_row1_col3" class="data row1 col3" >core-c1-d2</td>
#       <td id="T_1ba0e_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_1ba0e_row1_col5" class="data row1 col5" >config</td>
#       <td id="T_1ba0e_row1_col6" class="data row1 col6" ></td>
#       <td id="T_1ba0e_row1_col7" class="data row1 col7" >02:90:23:09:40:FF</td>
#       <td id="T_1ba0e_row1_col8" class="data row1 col8" >eth2</td>
#       <td id="T_1ba0e_row1_col9" class="data row1 col9" >eth2</td>
#       <td id="T_1ba0e_row1_col10" class="data row1 col10" >None</td>
#       <td id="T_1ba0e_row1_col11" class="data row1 col11" >6</td>
#     </tr>
#     <tr>
#       <td id="T_1ba0e_row2_col0" class="data row2 col0" >d1-eth4-p1</td>
#       <td id="T_1ba0e_row2_col1" class="data row2 col1" >p1</td>
#       <td id="T_1ba0e_row2_col2" class="data row2 col2" >d1</td>
#       <td id="T_1ba0e_row2_col3" class="data row2 col3" >core-a1-d1</td>
#       <td id="T_1ba
# Time to print interfaces 611 seconds

# %%
slice = fablib.get_slice(name=SLICE_NAME)
slice.show();
# slice.list_nodes()
# slice.list_networks()
# Out:
# <style type="text/css">
# #T_9c4f3 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_9c4f3 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_9c4f3 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_9c4f3_row0_col0, #T_9c4f3_row0_col1, #T_9c4f3_row1_col0, #T_9c4f3_row1_col1, #T_9c4f3_row2_col0, #T_9c4f3_row2_col1, #T_9c4f3_row3_col0, #T_9c4f3_row3_col1, #T_9c4f3_row4_col0, #T_9c4f3_row4_col1, #T_9c4f3_row5_col0, #T_9c4f3_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_9c4f3">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9c4f3_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_9c4f3_row0_col1" class="data row0 col1" >43263fc8-56e7-42e6-9f9e-cfd778508d91</td>
#     </tr>
#     <tr>
#       <td id="T_9c4f3_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_9c4f3_row1_col1" class="data row1 col1" >EIBP_2</td>
#     </tr>
#     <tr>
#       <td id="T_9c4f3_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_9c4f3_row2_col1" class="data row2 col1" >2023-12-07 14:09:56 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_9c4f3_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_9c4f3_row3_col1" class="data row3 col1" >2023-11-22 14:09:57 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_9c4f3_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_9c4f3_row4_col1" class="data row4 col1" >787adfc9-d37e-42f2-8efe-8e32793e0bb8</td>
#     </tr>
#     <tr>
#       <td id="T_9c4f3_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_9c4f3_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>

# %%
from FabUtils import FabOrchestrator

try:
    manager = FabOrchestrator(SLICE_NAME)

except Exception as e:
    print(f"Exception: {e}")

manager.saveSSHCommands()
# Out:
# Slice name: EIBP_1
# Slice and nodes were acquired successfully.

# %% [markdown]
# ## Add Basic IPv4 Addressing
#
# In this system, 192.168.0.0/16 is the address space for all interfaces on the FABRIC slice.
#
# Each network is a /24 subnet of this network. Edge networks have client/compute devices with lower address (ex: .1) and networking nodes with higher addresses.

# %%
from ipaddress import ip_address, IPv4Address, IPv4Network
#for node in slice.get_nodes():
#    node.execute("sudo systemctl stop NetworkManager.service")
# Start with a 1 in the third octet
thirdOctet = 1

# For each newtork in the slice
for network in slice.get_networks():
    # Grab all of the usable host addresses for a new network (new third octet).
    networkAddress = f'192.168.{thirdOctet}.0/24'
    currentIPNetwork = IPv4Network(networkAddress)
    hostIPList = list(currentIPNetwork)[1:-1] # 1:-1 = remove network and broadcast address

    # Determine if the current network is an edge or core network
    networkName = network.get_name()
    isEdgeNetwork = True if networkName.startswith("edge") else False

    print(f"Configuring network {networkName} with IPv4 Network {networkAddress}")

    # For each interface in the network
    for intf in network.get_interfaces():
        intfName = intf.get_device_name()
        intfNode = intf.get_node()
        nodeName = intf.get_node().get_name()
        intfNode.execute (f"sudo nmcli device set {intfName} managed no" )
        # If this is an edge network and it is a networking node, not the client node, give it a high-range address.
        if(isEdgeNetwork and not nodeDict[nodeName]["isClient"]):
            currentIPv4Address = hostIPList.pop() # Highest available host address in network
        else:
            currentIPv4Address = hostIPList.pop(0) # Lowest available host address in network

        # Add the address to the node
        intf.ip_addr_add(addr=currentIPv4Address, subnet=currentIPNetwork)
        print(f"\t{nodeName} {intf.get_device_name()} = {currentIPv4Address}")

    thirdOctet += 1
# Out:
# Configuring network core-c1-d2 with IPv4 Network 192.168.1.0/24
# 	d2 eth1 = 192.168.1.1
# 	c1 eth2 = 192.168.1.2
# Configuring network core-c1-d1 with IPv4 Network 192.168.2.0/24
# 	c1 eth1 = 192.168.2.1
# 	d1 eth3 = 192.168.2.2
# Configuring network core-a1-d2 with IPv4 Network 192.168.3.0/24
# 	a1 eth2 = 192.168.3.1
# 	d2 eth4 = 192.168.3.2
# Configuring network core-d1-a2 with IPv4 Network 192.168.4.0/24
# 	d1 eth1 = 192.168.4.1
# 	a2 eth2 = 192.168.4.2
# Configuring network core-d2-d1 with IPv4 Network 192.168.5.0/24
# 	d2 eth3 = 192.168.5.1
# 	d1 eth4 = 192.168.5.2
# Configuring network core-a1-d1 with IPv4 Network 192.168.6.0/24
# 	d1 eth2 = 192.168.6.1
# 	a1 eth1 = 192.168.6.2
# Configuring network core-d2-a2 with IPv4 Network 192.168.7.0/24
# 	d2 eth2 = 192.168.7.1
# 	a2 eth1 = 192.168.7.2
# Configuring network edge-a1-ipnode-1 with IPv4 Network 192.168.8.0/24
# 	a1 eth3 = 192.168.8.254
# 	ipnode-1 eth1 = 192.168.8.1
# Configuring network edge-a2-ipnode-2 with IPv4 Network 192.168.9.0/24
# 	ipnode-2 eth1 = 192.168.9.1
# 	a2 eth3 = 192.168.9.254
