# %% [markdown]
# # Prepare Code to be Run on EIBP Nodes

# %% [markdown]
# ## INITIALIZATION: Input Required Information
#
# | Variable | Use |
# | --- | --- |
# | SLICE_NAME    | Name of the slice you wish to work on. |
# | CONFIG_FILE | Configuration file for the nodes. |
# | CODE_DIR | Directory of the EIBP source code. |

# %%
SLICE_NAME = "eibp"
CONFIG_FILE = "config_small.txt"
CODE_DIR = "/home/fabric/work/MNLR_Code"

# %% [markdown]
# ## Access the Slice
#
# The orchestrator class is initalized, which also means the slice and its nodes are now accessable as well.

# %%
from FabUtils import FabOrchestrator

try:
    manager = FabOrchestrator(SLICE_NAME)
    
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Slice name: eibp
# Slice and nodes were acquired successfully.

# %% [markdown]
# ## KILL tmux session MNLR (if required)

# %%
stopCmd = "tmux kill-session -t MNLR"
manager.executeCommandsParallel(stopCmd, prefixList="a")
manager.executeCommandsParallel(stopCmd, prefixList="d")
manager.executeCommandsParallel(stopCmd, prefixList="c")
# Out:
# Starting command on node a1
# Command to execute: tmux kill-session -t MNLR
# Starting command on node a2
# Command to execute: tmux kill-session -t MNLR
# Waiting for result from node a1
# stdout:
# stderr: no server running on /tmp/tmux-1000/default
#
# Waiting for result from node a2
# stdout:
# stderr: no server running on /tmp/tmux-1000/default
#
# Starting command on node d1
# Command to execute: tmux kill-session -t MNLR
# Starting command on node d2
# Command to execute: tmux kill-session -t MNLR
# Waiting for result from node d1
# stdout:
# stderr: no server running on /tmp/tmux-1000/default
#
# Waiting for result from node d2
# stdout:
# stderr: no server running on /tmp/tmux-1000/default
#
# Starting command on node c1
# Command to execute: tmux kill-session -t MNLR
# Waiting for result from node c1
# stdout:
# stderr: no server running on /tmp/tmux-1000/default

# %% [markdown]
# ## Delete the Log from a Prior Test (if required)
#
# This code is executing the command to remove log files with names starting with "EIBP_" for three nodes (prefixes): "c," "d," and "a," using a manager's function called "executeCommandsParallel."

# %%
rmLogCmd = "rm EIBP_*.log"
manager.executeCommandsParallel(rmLogCmd, prefixList="c,d,a")
# Out:
# Starting command on node c1
# Command to execute: rm EIBP_*.log
# Starting command on node d1
# Command to execute: rm EIBP_*.log
# Starting command on node d2
# Command to execute: rm EIBP_*.log
# Starting command on node a1
# Command to execute: rm EIBP_*.log
# Starting command on node a2
# Command to execute: rm EIBP_*.log
# Waiting for result from node c1
# stdout:
# stderr:
# Waiting for result from node d1
# stdout:
# stderr:
# Waiting for result from node d2
# stdout:
# stderr:
# Waiting for result from node a1
# stdout:
# stderr:
# Waiting for result from node a2
# stdout:
# stderr:

# %% [markdown]
# ## Delete MNLR_Code in the slice (if required)
#
# This code is executing the "rm -rf MNLR_Code/" command to recursively delete the directory "MNLR_Code" in for three prefixes: "c," "d," and "a," using a manager's function called "executeCommandsParallel.

# %%
deleteexec= "rm -rf MNLR_Code/"
manager.executeCommandsParallel(deleteexec, prefixList="c,d,a")
# Out:
# Starting command on node c1
# Command to execute: rm -rf MNLR_Code/
# Starting command on node d1
# Command to execute: rm -rf MNLR_Code/
# Starting command on node d2
# Command to execute: rm -rf MNLR_Code/
# Starting command on node a1
# Command to execute: rm -rf MNLR_Code/
# Starting command on node a2
# Command to execute: rm -rf MNLR_Code/
# Waiting for result from node c1
# stdout:
# stderr:
# Waiting for result from node d1
# stdout:
# stderr:
# Waiting for result from node d2
# stdout:
# stderr:
# Waiting for result from node a1
# stdout:
# stderr:
# Waiting for result from node a2
# stdout:
# stderr:

# %% [markdown]
# ## Upload the Source Code
#
# This code is uploading the directory specified by the variable "CODE_DIR" to multiple destinations( all the nodes), identified by the prefixes "c," "d," and "a," using a manager's function called "uploadDirectoryParallel."

# %%
manager.uploadDirectoryParallel(CODE_DIR, prefixList="c,d,a")
# Out:
# Directory to upload: /home/fabric/work/MNLR_Code
# Placed in: /home/rocky
# Starting upload on node c1
# Starting upload on node d1
# Starting upload on node d2
# Starting upload on node a1
# Starting upload on node a2
# Waiting for result from node c1
# Upload on node c1 was successful
# Waiting for result from node d1
# Upload on node d1 was successful
# Waiting for result from node d2
# Upload on node d2 was successful
# Waiting for result from node a1
# Upload on node a1 was successful
# Waiting for result from node a2
# Upload on node a2 was successful

# %% [markdown]
# ## Compile the Code
#
# This code compiles C source files in the "MNLR_Code/" directory into an executable named "MNLR" using GCC, with debugging and error handling flags in all nodes.

# %%
compileCmd = "cd MNLR_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm"
manager.executeCommandsParallel(compileCmd, prefixList="c,d,a")
# Out:
# Starting command on node c1
# Command to execute: cd MNLR_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm
# Starting command on node d1
# Command to execute: cd MNLR_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm
# Starting command on node d2
# Command to execute: cd MNLR_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm
# Starting command on node a1
# Command to execute: cd MNLR_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm
# Starting command on node a2
# Command to execute: cd MNLR_Code/; gcc -g -Wfatal-errors -o MNLR *.c -lm
# Waiting for result from node c1
# stdout:
# stderr: endNW.c: In function ‘delete_entry_LL_Addr’:
# endNW.c:174:7: warning: implicit declaration of function ‘publishIPLabelMap’ [-Wimplicit-function-declaration]
#        publishIPLabelMap(current->tier_addr,1);
#        ^~~~~~~~~~~~~~~~~
# endNW.c: In function ‘updateEndTierAddr’:
# endNW.c:693:3: warning: implicit declaration of function ‘printAddresstoResponse’ [-Wimplicit-function-declaration]
#    printAddresstoResponse();
#    ^~~~~~~~~~~~~~~~~~~~~~
# endNW.c:733:3: warning: implicit declaration of function ‘requestIPresolve’ [-Wimplicit-function-declaration]
#    requestIPresolve(destinationInterfaceIPAddr,Mytier);
#    ^~~~~~~~~~~~~~~~
# In file included from helloList.h:19,
#                  from helloM_List.c:22:
# tierList.h: In function ‘deleteTierAddr’:
# tierList.h:191:8: warning: implicit declaration of function ‘notify_myLabels_Update’ [-Wimplicit-function-declaration]
#         notify_myLabels_Update(2,tempDel);
#         ^~~~~~~~~~~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h: In function ‘append’:
# helloList.h:90:19: warning: implicit declaration of function ‘matchPort’ [-Wimplicit-function-declaration]
#   int match_Port = matchPort(inPort);
#                    ^~~~~~~~~
# helloList.h:92:3: warning: implicit declaration of function ‘tagport’; did you mean ‘abort’? [-Wimplicit-function-declaration]
#    tagport(inPort,1);
#    ^~~~~~~
#    abort
# helloList.h: In function ‘staging’:
# helloList.h:340:24: warning: implicit declaration of function ‘findStable’; did you mean ‘findPortName’? [-Wimplicit-function-declaration]
#   int checkstableport = findStable(inPort);
#                         ^~~~~~~~~~
#                         findPortName
# helloList.h:345:22: warning: implicit declaration of function ‘findStaging’; did you mean ‘staging’? [-Wimplicit-function-declaration]
#    int checkStaging = findStaging(inPort);
#                       ^~~~~~~~~~~
#                       staging
# helloList.h:372:13: warning: implicit declaration of function ‘updateStaging’ [-Wimplicit-function-declaration]
#     stable = updateStaging(inPort);
#              ^~~~~~~~~~~~~
# helloList.h: In function ‘insert’:
# helloList.h:401:3: warning: implicit declaration of function ‘printMyLabels’ [-Wimplicit-function-declaration]
#    printMyLabels();
#    ^~~~~~~~~~~~~
# helloList.h: In function ‘delete’:
# helloList.h:724:6: warning: implicit declaration of function ‘notify_lostmychild’ [-Wimplicit-function-declaration]
#       notify_lostmychild(temp->port);
#       ^~~~~~~~~~~~~~~~~~
# helloList.h:754:8: warning: implicit declaration of function ‘deleteIPLabel’; did you mean ‘deleteStable’? [-Wimplicit-function-declaration]
#         deleteIPLabel(temp->port);
#         ^~~~~~~~~~~~~
#         deleteStable
# helloList.h: In function ‘deleteTag’:
# helloList.h:883:17: warning: comparison of distinct pointer types lacks a cast
#        if (fNode == headStable) {
#                  ^~
# helloList.h:885:19: warning: assignment to ‘struct stablePort *’ from incompatible pointer type ‘struct portTag *’ [-Wincompatible-pointer-types]
#         headStable = fNode->next;
#                    ^
# helloM_List.c: At top level:
# helloM_List.c:153:6: warning: conflicting types for ‘printMyLabels’
#  void printMyLabels();
#       ^~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h:401:3: note: previous implicit declaration of ‘printMyLabels’ was here
#    printMyLabels();
#    ^~~~~~~~~~~~~
# helloM_List.c: In function ‘_get_MACTest’:
# helloM_List.c:483:28: warning: passing argument 1 of ‘delete_failed_LL_Addr’ from incompatible pointer type [-Wincompatible-pointer-types]
#       delete_failed_LL_Addr(failedLL_head);
#                             ^~~~~~~~~~~~~
# In file included from helloList.h:20,
#                  from helloM_List.c:22:
# endNetworkUtils.h:50:28: note: expected ‘uint8_t *’ {aka ‘unsigned char *’} but argument is of type ‘struct addr_tuple *’
#  void delete_failed_LL_Addr(uint8_t* );
#                             ^~~~~~~~
# helloM_List.c: In function ‘sendNullJoin’:
# helloM_List.c:1219:35: warning: passing argument 2 of ‘ctrlLabelSend’ from incompatible pointer type [-Wincompatible-pointer-types]
#   ctrlLabelSend(MESSAGE_TYPE_JOIN, to_port, labelAssignmentPayLoad);
#                                    ^~~~~~~
# helloM_List.c:33:36: note: expected ‘char *’ but argument is of type ‘int *’
#  extern int ctrlLabelSend(int, char eth[], char pay[]);
#                                ~~~~~^~~~~
# helloM_List.c: At top level:
# helloM_List.c:1564:6: warning: conflicting types for ‘notify_lostmychild’
#  void notify_lostmychild(char port[20]) {
#       ^~~~~~~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h:724:6: note: previous implicit declaration of ‘notify_lostmychild’ was here
#       notify_lostmychild(temp->port);
#       ^~~~~~~~~~~~~~~~~~
# helloM_List.c:1668:6: warning: conflicting types for ‘notify_myLabels_Update’
#  void notify_myLabels_Update(int update_action, char inTier[20]) {
#       ^~~~~~~~~~~~~~~~~~~~~~
# In file included from helloList.h:19,
#                  from helloM_List.c:22:
# tierList.h:191:8: note: previous implicit declaration of ‘notify_myLabels_Update’ was here
#         notify_myLabels_Update(2,tempDel);
#         ^~~~~~~~~~~~~~~~~~~~~~
# helloM_List.c: In function ‘responseIPresolve’:
# helloM_List.c:1804:20: warning: implicit declaration of function ‘buildIPResolvePacket’ [-Wimplicit-function-declaration]
#    mplrPayloadLen = buildIPResolvePacket(mplrPayload, DestTierLabel, tierValue);
#                     ^~~~~~~~~~~~~~~~~~~~
# helloM_List.c: At top level:
# helloM_List.c:1844:6: warning: conflicting types for ‘deleteIPLabel’
#  void deleteIPLabel(char failedEth[]) {
#       ^~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h:754:8: note: previous implicit declaration of ‘deleteIPLabel’ was here
#         deleteIPLabel(temp->port);
#         ^~~~~~~~~~~~~
# helloM_List.c: In function ‘publishIPLabelMap’:
# helloM_List.c:1938:20: warning: implicit declaration of function ‘buildIPPublishPacket’ [-Wimplicit-function-declaration]
#    mplrPayloadLen = buildIPPublishPacket(mplrPayload, label);
#                     ^~~~~~~~~~~~~~~~~~~~
# helloM_List.c: In function ‘findParentofDestination’:
# helloM_List.c:1959:17: warning: implicit declaration of function ‘getParent’; did you mean ‘getservent’? [-Wimplicit-function-declaration]
#   parentofDest = getParent(DestTierLabel, '.');
#                  ^~~~~~~~~
#                  getservent
# helloM_List.c:1959:15: warning: assignment to ‘char *’ from ‘int’ makes pointer from integer without a cast [-Wint-conversion]
#   parentofDest = getParent(DestTierLabel, '.');
#                ^
# helloM_List.c: In function ‘hello_msg’:
# helloM_List.c:2110:17: warning: passing argument 1 of ‘sendNullJoin’ from incompatible pointer type [-Wincompatible-pointer-types]
#     sendNullJoin(recvOnEtherPort);
#                  ^~~~~~~~~~~~~~~
# helloM_List.c:1205:23: note: expected ‘int *’ but argument is of type ‘char *’
#  void sendNullJoin(int to_port[20]) {
#                    ~~~~^~~~~~~~~~~
# helloM_List.c:2122:18: warning: passing argument 1 of ‘sendNullJoin’ from incompatible pointer type [-Wincompatible-pointer-types]
#      sendNullJoin(recvOnEtherPort);
#                   ^~~~~~~~~~~~~~~
# helloM_List.c:1205:23: note: expected ‘int *’ but argument is of type ‘char *’
#  void sendNullJoin(int to_port[20]) {
#                    ~~~~^~~~~~~~~~~
# helloM_List.c: In function ‘msg_typ_labl_add’:
# helloM_List.c:2696:16: warning: passing argument 1 of ‘sendNullJoin’ from incompatible pointer type [-Wincompatible-pointer-types]
#    sendNullJoin(recvOnEtherPort);
#                 ^~~~~~~~~~~~~~~
# helloM_List.c:1205:23: note: expected ‘int *’ but argument is of type ‘char *’
#  void sendNullJoin(int to_port[20]) {
#                    ~~~~^~~~~~~~~~~
# helloM_List.c: In function ‘msg_typ_labl_delt’:
# helloM_List.c:2762:24: warning: passing argument 1 of ‘delete_failed_LL_Addr’ from incompatible pointer type [-Wincompatible-pointer-types]
#   delete_failed_LL_Addr(failedLL_head);
#                         ^~~~~~~~~~~~~
# In file included from helloList.h:20,
#                  from helloM_List.c:22:
# endNetworkUtils.h:50:28: note: expected ‘uint8_t *’ {aka ‘unsigned char *’} but argument is of type ‘struct addr_tuple *’
#  void delete_failed_LL_Addr(uint8_t* );
#                             ^~~~~~~~
# helloM_List.c: In function ‘msg_typ_rqst_ip’:
# helloM_List.c:2816:3: warning: implicit declaration of function ‘findIPforLabel’; did you mean ‘findPortName’? [-Wimplicit-function-declaration]
#    findIPforLabel(MytierAddrTemp, mylabelIP);
#    ^~~~~~~~~~~~~~
#    findPortName
# helloM_List.c: In function ‘msg_typ_ip_add’:
# helloM_List.c:3123:49: warning: implicit declaration of function ‘searchIPinMyMap’ [-Wimplicit-function-declaration]
#    if (strcmp(ip_add, inet_ntoa(ipAddr)) == 0 || searchIPinMyMap(inet_ntoa(ipAddr)) == 0) {
#                                                  ^~~~~~~~~~~~~~~
#
# Waiting for result from node d1
# stdout:
# stderr: endNW.c: In function ‘delete_entry_LL_Addr’:
# endNW.c:174:7: warning: implicit declaration of function ‘publishIPLabelMap’ [-Wimplicit-function-declaration]
#        publishIPLabelMap(current->tier_addr,1);
#        ^~~~~~~~~~~~~~~~~
# endNW.c: In function ‘updateEndTierAddr’:
# endNW.c:693:3: warning: implicit declaration of function ‘printAddresstoResponse’ [-Wimplicit-function-declaration]
#    printAddresstoResponse();
#    ^~~~~~~~~~~~~~~~~~~~~~
# endNW.c:733:3: warning: implicit declaration of function ‘requestIPresolve’ [-Wimplicit-function-declaration]
#    requestIPresolve(destinationInterfaceIPAddr,Mytier);
#    ^~~~~~~~~~~~~~~~
# In file included from helloList.h:19,
#                  from helloM_List.c:22:
# tierList.h: In function ‘deleteTierAddr’:
# tierList.h:191:8: warning: implicit declaration of function ‘notify_myLabels_Update’ [-Wimplicit-function-declaration]
#         notify_myLabels_Update(2,tempDel);
#         ^~~~~~~~~~~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h: In function ‘append’:
# helloList.h:90:19: warning: implicit declaration of function ‘matchPort’ [-Wimplicit-function-declaration]
#   int match_Port = matchPort(inPort);
#                    ^~~~~~~~~
# helloList.h:92:3: warning: implicit declaration of function ‘tagport’; did you mean ‘abort’? [-Wimplicit-function-declaration]
#    tagport(inPort,1);
#    ^~~~~~~
#    abort
# helloList.h: In function ‘staging’:
# helloList.h:340:24: warning: implicit declaration of function ‘findStable’; did you mean ‘findPortName’? [-Wimplicit-function-declaration]
#   int checkstableport = findStable(inPort);
#                         ^~~~~~~~~~
#                         findPortName
# helloList.h:345:22: warning: implicit declaration of function ‘findStaging’; did you mean ‘staging’? [-Wimplicit-function-declaration]
#    int checkStaging = findStaging(inPort);
#                       ^~~~~~~~~~~
#                       staging
# helloList.h:372:13: warning: implicit declaration of function ‘updateStaging’ [-Wimplicit-function-declaration]
#     stable = updateStaging(inPort);
#              ^~~~~~~~~~~~~
# helloList.h: In function ‘insert’:
# helloList.h:401:3: warning: implicit declaration of function ‘printMyLabels’ [-Wimplicit-function-declaration]
#    printMyLabels();
#    ^~~~~~~~~~~~~
# helloList.h: In function ‘delete’:
# helloList.h:724:6: warning: implicit declaration of function ‘notify_lostmychild’ [-Wimplicit-function-declaration]
#       notify_lostmychild(temp->port);
#       ^~~~~~~~~~~~~~~~~~
# helloList.h:754:8: warning: implicit declaration of function ‘deleteIPLabel’; did you mean ‘deleteStable’? [-Wimplicit-function-declaration]
#         deleteIPLabel(temp->port);
#         ^~~~~~~~~~~~~
#         deleteStable
# helloList.h: In function ‘deleteTag’:
# helloList.h:883:17: warning: comparison of distinct pointer types lacks a cast
#        if (fNode == headStable) {
#                  ^~
# helloList.h:885:19: warning: assignment to ‘struct stablePort *’ from incompatible pointer type ‘struct portTag *’ [-Wincompatible-pointer-types]
#         headStable = fNode->next;
#                    ^
# helloM_List.c: At top level:
# helloM_List.c:153:6: warning: conflicting types for ‘printMyLabels’
#  void printMyLabels();
#       ^~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h:401:3: note: previous implicit declaration of ‘printMyLabels’ was here
#    printMyLabels();
#    ^~~~~~~~~~~~~
# helloM_List.c: In function ‘_get_MACTest’:
# helloM_List.c:483:28: warning: passing argument 1 of ‘delete_failed_LL_Addr’ from incompatible pointer type [-Wincompatible-pointer-types]
#       delete_failed_LL_Addr(failedLL_head);
#                             ^~~~~~~~~~~~~
# In file included from helloList.h:20,
#                  from helloM_List.c:22:
# endNetworkUtils.h:50:28: note: expected ‘uint8_t *’ {aka ‘unsigned char *’} but argument is of type ‘struct addr_tuple *’
#  void delete_failed_LL_Addr(uint8_t* );
#                             ^~~~~~~~
# helloM_List.c: In function ‘sendNullJoin’:
# helloM_List.c:1219:35: warning: passing argument 2 of ‘ctrlLabelSend’ from incompatible pointer type [-Wincompatible-pointer-types]
#   ctrlLabelSend(MESSAGE_TYPE_JOIN, to_port, labelAssignmentPayLoad);
#                                    ^~~~~~~
# helloM_List.c:33:36: note: expected ‘char *’ but argument is of type ‘int *’
#  extern int ctrlLabelSend(int, char eth[], char pay[]);
#                                ~~~~~^~~~~
# helloM_List.c: At top level:
# helloM_List.c:1564:6: warning: conflicting types for ‘notify_lostmychild’
#  void notify_lostmychild(char port[20]) {
#       ^~~~~~~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h:724:6: note: previous implicit declaration of ‘notify_lostmychild’ was here
#       notify_lostmychild(temp->port);
#       ^~~~~~~~~~~~~~~~~~
# helloM_List.c:1668:6: warning: conflicting types for ‘notify_myLabels_Update’
#  void notify_myLabels_Update(int update_action, char inTier[20]) {
#       ^~~~~~~~~~~~~~~~~~~~~~
# In file included from helloList.h:19,
#                  from helloM_List.c:22:
# tierList.h:191:8: note: previous implicit declaration of ‘notify_myLabels_Update’ was here
#         notify_myLabels_Update(2,tempDel);
#         ^~~~~~~~~~~~~~~~~~~~~~
# helloM_List.c: In function ‘responseIPresolve’:
# helloM_List.c:1804:20: warning: implicit declaration of function ‘buildIPResolvePacket’ [-Wimplicit-function-declaration]
#    mplrPayloadLen = buildIPResolvePacket(mplrPayload, DestTierLabel, tierValue);
#                     ^~~~~~~~~~~~~~~~~~~~
# helloM_List.c: At top level:
# helloM_List.c:1844:6: warning: conflicting types for ‘deleteIPLabel’
#  void deleteIPLabel(char failedEth[]) {
#       ^~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h:754:8: note: previous implicit declaration of ‘deleteIPLabel’ was here
#         deleteIPLabel(temp->port);
#         ^~~~~~~~~~~~~
# helloM_List.c: In function ‘publishIPLabelMap’:
# helloM_List.c:1938:20: warning: implicit declaration of function ‘buildIPPublishPacket’ [-Wimplicit-function-declaration]
#    mplrPayloadLen = buildIPPublishPacket(mplrPayload, label);
#                     ^~~~~~~~~~~~~~~~~~~~
# helloM_List.c: In function ‘findParentofDestination’:
# helloM_List.c:1959:17: warning: implicit declaration of function ‘getParent’; did you mean ‘getservent’? [-Wimplicit-function-declaration]
#   parentofDest = getParent(DestTierLabel, '.');
#                  ^~~~~~~~~
#                  getservent
# helloM_List.c:1959:15: warning: assignment to ‘char *’ from ‘int’ makes pointer from integer without a cast [-Wint-conversion]
#   parentofDest = getParent(DestTierLabel, '.');
#                ^
# helloM_List.c: In function ‘hello_msg’:
# helloM_List.c:2110:17: warning: passing argument 1 of ‘sendNullJoin’ from incompatible pointer type [-Wincompatible-pointer-types]
#     sendNullJoin(recvOnEtherPort);
#                  ^~~~~~~~~~~~~~~
# helloM_List.c:1205:23: note: expected ‘int *’ but argument is of type ‘char *’
#  void sendNullJoin(int to_port[20]) {
#                    ~~~~^~~~~~~~~~~
# helloM_List.c:2122:18: warning: passing argument 1 of ‘sendNullJoin’ from incompatible pointer type [-Wincompatible-pointer-types]
#      sendNullJoin(recvOnEtherPort);
#                   ^~~~~~~~~~~~~~~
# helloM_List.c:1205:23: note: expected ‘int *’ but argument is of type ‘char *’
#  void sendNullJoin(int to_port[20]) {
#                    ~~~~^~~~~~~~~~~
# helloM_List.c: In function ‘msg_typ_labl_add’:
# helloM_List.c:2696:16: warning: passing argument 1 of ‘sendNullJoin’ from incompatible pointer type [-Wincompatible-pointer-types]
#    sendNullJoin(recvOnEtherPort);
#                 ^~~~~~~~~~~~~~~
# helloM_List.c:1205:23: note: expected ‘int *’ but argument is of type ‘char *’
#  void sendNullJoin(int to_port[20]) {
#                    ~~~~^~~~~~~~~~~
# helloM_List.c: In function ‘msg_typ_labl_delt’:
# helloM_List.c:2762:24: warning: passing argument 1 of ‘delete_failed_LL_Addr’ from incompatible pointer type [-Wincompatible-pointer-types]
#   delete_failed_LL_Addr(failedLL_head);
#                         ^~~~~~~~~~~~~
# In file included from helloList.h:20,
#                  from helloM_List.c:22:
# endNetworkUtils.h:50:28: note: expected ‘uint8_t *’ {aka ‘unsigned char *’} but argument is of type ‘struct addr_tuple *’
#  void delete_failed_LL_Addr(uint8_t* );
#                             ^~~~~~~~
# helloM_List.c: In function ‘msg_typ_rqst_ip’:
# helloM_List.c:2816:3: warning: implicit declaration of function ‘findIPforLabel’; did you mean ‘findPortName’? [-Wimplicit-function-declaration]
#    findIPforLabel(MytierAddrTemp, mylabelIP);
#    ^~~~~~~~~~~~~~
#    findPortName
# helloM_List.c: In function ‘msg_typ_ip_add’:
# helloM_List.c:3123:49: warning: implicit declaration of function ‘searchIPinMyMap’ [-Wimplicit-function-declaration]
#    if (strcmp(ip_add, inet_ntoa(ipAddr)) == 0 || searchIPinMyMap(inet_ntoa(ipAddr)) == 0) {
#                                                  ^~~~~~~~~~~~~~~
#
# Waiting for result from node d2
# stdout:
# stderr: endNW.c: In function ‘delete_entry_LL_Addr’:
# endNW.c:174:7: warning: implicit declaration of function ‘publishIPLabelMap’ [-Wimplicit-function-declaration]
#        publishIPLabelMap(current->tier_addr,1);
#        ^~~~~~~~~~~~~~~~~
# endNW.c: In function ‘updateEndTierAddr’:
# endNW.c:693:3: warning: implicit declaration of function ‘printAddresstoResponse’ [-Wimplicit-function-declaration]
#    printAddresstoResponse();
#    ^~~~~~~~~~~~~~~~~~~~~~
# endNW.c:733:3: warning: implicit declaration of function ‘requestIPresolve’ [-Wimplicit-function-declaration]
#    requestIPresolve(destinationInterfaceIPAddr,Mytier);
#    ^~~~~~~~~~~~~~~~
# In file included from helloList.h:19,
#                  from helloM_List.c:22:
# tierList.h: In function ‘deleteTierAddr’:
# tierList.h:191:8: warning: implicit declaration of function ‘notify_myLabels_Update’ [-Wimplicit-function-declaration]
#         notify_myLabels_Update(2,tempDel);
#         ^~~~~~~~~~~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h: In function ‘append’:
# helloList.h:90:19: warning: implicit declaration of function ‘matchPort’ [-Wimplicit-function-declaration]
#   int match_Port = matchPort(inPort);
#                    ^~~~~~~~~
# helloList.h:92:3: warning: implicit declaration of function ‘tagport’; did you mean ‘abort’? [-Wimplicit-function-declaration]
#    tagport(inPort,1);
#    ^~~~~~~
#    abort
# helloList.h: In function ‘staging’:
# helloList.h:340:24: warning: implicit declaration of function ‘findStable’; did you mean ‘findPortName’? [-Wimplicit-function-declaration]
#   int checkstableport = findStable(inPort);
#                         ^~~~~~~~~~
#                         findPortName
# helloList.h:345:22: warning: implicit declaration of function ‘findStaging’; did you mean ‘staging’? [-Wimplicit-function-declaration]
#    int checkStaging = findStaging(inPort);
#                       ^~~~~~~~~~~
#                       staging
# helloList.h:372:13: warning: implicit declaration of function ‘updateStaging’ [-Wimplicit-function-declaration]
#     stable = updateStaging(inPort);
#              ^~~~~~~~~~~~~
# helloList.h: In function ‘insert’:
# helloList.h:401:3: warning: implicit declaration of function ‘printMyLabels’ [-Wimplicit-function-declaration]
#    printMyLabels();
#    ^~~~~~~~~~~~~
# helloList.h: In function ‘delete’:
# helloList.h:724:6: warning: implicit declaration of function ‘notify_lostmychild’ [-Wimplicit-function-declaration]
#       notify_lostmychild(temp->port);
#       ^~~~~~~~~~~~~~~~~~
# helloList.h:754:8: warning: implicit declaration of function ‘deleteIPLabel’; did you mean ‘deleteStable’? [-Wimplicit-function-declaration]
#         deleteIPLabel(temp->port);
#         ^~~~~~~~~~~~~
#         deleteStable
# helloList.h: In function ‘deleteTag’:
# helloList.h:883:17: warning: comparison of distinct pointer types lacks a cast
#        if (fNode == headStable) {
#                  ^~
# helloList.h:885:19: warning: assignment to ‘struct stablePort *’ from incompatible pointer type ‘struct portTag *’ [-Wincompatible-pointer-types]
#         headStable = fNode->next;
#                    ^
# helloM_List.c: At top level:
# helloM_List.c:153:6: warning: conflicting types for ‘printMyLabels’
#  void printMyLabels();
#       ^~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h:401:3: note: previous implicit declaration of ‘printMyLabels’ was here
#    printMyLabels();
#    ^~~~~~~~~~~~~
# helloM_List.c: In function ‘_get_MACTest’:
# helloM_List.c:483:28: warning: passing argument 1 of ‘delete_failed_LL_Addr’ from incompatible pointer type [-Wincompatible-pointer-types]
#       delete_failed_LL_Addr(failedLL_head);
#                             ^~~~~~~~~~~~~
# In file included from helloList.h:20,
#                  from helloM_List.c:22:
# endNetworkUtils.h:50:28: note: expected ‘uint8_t *’ {aka ‘unsigned char *’} but argument is of type ‘struct addr_tuple *’
#  void delete_failed_LL_Addr(uint8_t* );
#                             ^~~~~~~~
# helloM_List.c: In function ‘sendNullJoin’:
# helloM_List.c:1219:35: warning: passing argument 2 of ‘ctrlLabelSend’ from incompatible pointer type [-Wincompatible-pointer-types]
#   ctrlLabelSend(MESSAGE_TYPE_JOIN, to_port, labelAssignmentPayLoad);
#                                    ^~~~~~~
# helloM_List.c:33:36: note: expected ‘char *’ but argument is of type ‘int *’
#  extern int ctrlLabelSend(int, char eth[], char pay[]);
#                                ~~~~~^~~~~
# helloM_List.c: At top level:
# helloM_List.c:1564:6: warning: conflicting types for ‘notify_lostmychild’
#  void notify_lostmychild(char port[20]) {
#       ^~~~~~~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h:724:6: note: previous implicit declaration of ‘notify_lostmychild’ was here
#       notify_lostmychild(temp->port);
#       ^~~~~~~~~~~~~~~~~~
# helloM_List.c:1668:6: warning: conflicting types for ‘notify_myLabels_Update’
#  void notify_myLabels_Update(int update_action, char inTier[20]) {
#       ^~~~~~~~~~~~~~~~~~~~~~
# In file included from helloList.h:19,
#                  from helloM_List.c:22:
# tierList.h:191:8: note: previous implicit declaration of ‘notify_myLabels_Update’ was here
#         notify_myLabels_Update(2,tempDel);
#         ^~~~~~~~~~~~~~~~~~~~~~
# helloM_List.c: In function ‘responseIPresolve’:
# helloM_List.c:1804:20: warning: implicit declaration of function ‘buildIPResolvePacket’ [-Wimplicit-function-declaration]
#    mplrPayloadLen = buildIPResolvePacket(mplrPayload, DestTierLabel, tierValue);
#                     ^~~~~~~~~~~~~~~~~~~~
# helloM_List.c: At top level:
# helloM_List.c:1844:6: warning: conflicting types for ‘deleteIPLabel’
#  void deleteIPLabel(char failedEth[]) {
#       ^~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h:754:8: note: previous implicit declaration of ‘deleteIPLabel’ was here
#         deleteIPLabel(temp->port);
#         ^~~~~~~~~~~~~
# helloM_List.c: In function ‘publishIPLabelMap’:
# helloM_List.c:1938:20: warning: implicit declaration of function ‘buildIPPublishPacket’ [-Wimplicit-function-declaration]
#    mplrPayloadLen = buildIPPublishPacket(mplrPayload, label);
#                     ^~~~~~~~~~~~~~~~~~~~
# helloM_List.c: In function ‘findParentofDestination’:
# helloM_List.c:1959:17: warning: implicit declaration of function ‘getParent’; did you mean ‘getservent’? [-Wimplicit-function-declaration]
#   parentofDest = getParent(DestTierLabel, '.');
#                  ^~~~~~~~~
#                  getservent
# helloM_List.c:1959:15: warning: assignment to ‘char *’ from ‘int’ makes pointer from integer without a cast [-Wint-conversion]
#   parentofDest = getParent(DestTierLabel, '.');
#                ^
# helloM_List.c: In function ‘hello_msg’:
# helloM_List.c:2110:17: warning: passing argument 1 of ‘sendNullJoin’ from incompatible pointer type [-Wincompatible-pointer-types]
#     sendNullJoin(recvOnEtherPort);
#                  ^~~~~~~~~~~~~~~
# helloM_List.c:1205:23: note: expected ‘int *’ but argument is of type ‘char *’
#  void sendNullJoin(int to_port[20]) {
#                    ~~~~^~~~~~~~~~~
# helloM_List.c:2122:18: warning: passing argument 1 of ‘sendNullJoin’ from incompatible pointer type [-Wincompatible-pointer-types]
#      sendNullJoin(recvOnEtherPort);
#                   ^~~~~~~~~~~~~~~
# helloM_List.c:1205:23: note: expected ‘int *’ but argument is of type ‘char *’
#  void sendNullJoin(int to_port[20]) {
#                    ~~~~^~~~~~~~~~~
# helloM_List.c: In function ‘msg_typ_labl_add’:
# helloM_List.c:2696:16: warning: passing argument 1 of ‘sendNullJoin’ from incompatible pointer type [-Wincompatible-pointer-types]
#    sendNullJoin(recvOnEtherPort);
#                 ^~~~~~~~~~~~~~~
# helloM_List.c:1205:23: note: expected ‘int *’ but argument is of type ‘char *’
#  void sendNullJoin(int to_port[20]) {
#                    ~~~~^~~~~~~~~~~
# helloM_List.c: In function ‘msg_typ_labl_delt’:
# helloM_List.c:2762:24: warning: passing argument 1 of ‘delete_failed_LL_Addr’ from incompatible pointer type [-Wincompatible-pointer-types]
#   delete_failed_LL_Addr(failedLL_head);
#                         ^~~~~~~~~~~~~
# In file included from helloList.h:20,
#                  from helloM_List.c:22:
# endNetworkUtils.h:50:28: note: expected ‘uint8_t *’ {aka ‘unsigned char *’} but argument is of type ‘struct addr_tuple *’
#  void delete_failed_LL_Addr(uint8_t* );
#                             ^~~~~~~~
# helloM_List.c: In function ‘msg_typ_rqst_ip’:
# helloM_List.c:2816:3: warning: implicit declaration of function ‘findIPforLabel’; did you mean ‘findPortName’? [-Wimplicit-function-declaration]
#    findIPforLabel(MytierAddrTemp, mylabelIP);
#    ^~~~~~~~~~~~~~
#    findPortName
# helloM_List.c: In function ‘msg_typ_ip_add’:
# helloM_List.c:3123:49: warning: implicit declaration of function ‘searchIPinMyMap’ [-Wimplicit-function-declaration]
#    if (strcmp(ip_add, inet_ntoa(ipAddr)) == 0 || searchIPinMyMap(inet_ntoa(ipAddr)) == 0) {
#                                                  ^~~~~~~~~~~~~~~
#
# Waiting for result from node a1
# stdout:
# stderr: endNW.c: In function ‘delete_entry_LL_Addr’:
# endNW.c:174:7: warning: implicit declaration of function ‘publishIPLabelMap’ [-Wimplicit-function-declaration]
#        publishIPLabelMap(current->tier_addr,1);
#        ^~~~~~~~~~~~~~~~~
# endNW.c: In function ‘updateEndTierAddr’:
# endNW.c:693:3: warning: implicit declaration of function ‘printAddresstoResponse’ [-Wimplicit-function-declaration]
#    printAddresstoResponse();
#    ^~~~~~~~~~~~~~~~~~~~~~
# endNW.c:733:3: warning: implicit declaration of function ‘requestIPresolve’ [-Wimplicit-function-declaration]
#    requestIPresolve(destinationInterfaceIPAddr,Mytier);
#    ^~~~~~~~~~~~~~~~
# In file included from helloList.h:19,
#                  from helloM_List.c:22:
# tierList.h: In function ‘deleteTierAddr’:
# tierList.h:191:8: warning: implicit declaration of function ‘notify_myLabels_Update’ [-Wimplicit-function-declaration]
#         notify_myLabels_Update(2,tempDel);
#         ^~~~~~~~~~~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h: In function ‘append’:
# helloList.h:90:19: warning: implicit declaration of function ‘matchPort’ [-Wimplicit-function-declaration]
#   int match_Port = matchPort(inPort);
#                    ^~~~~~~~~
# helloList.h:92:3: warning: implicit declaration of function ‘tagport’; did you mean ‘abort’? [-Wimplicit-function-declaration]
#    tagport(inPort,1);
#    ^~~~~~~
#    abort
# helloList.h: In function ‘staging’:
# helloList.h:340:24: warning: implicit declaration of function ‘findStable’; did you mean ‘findPortName’? [-Wimplicit-function-declaration]
#   int checkstableport = findStable(inPort);
#                         ^~~~~~~~~~
#                         findPortName
# helloList.h:345:22: warning: implicit declaration of function ‘findStaging’; did you mean ‘staging’? [-Wimplicit-function-declaration]
#    int checkStaging = findStaging(inPort);
#                       ^~~~~~~~~~~
#                       staging
# helloList.h:372:13: warning: implicit declaration of function ‘updateStaging’ [-Wimplicit-function-declaration]
#     stable = updateStaging(inPort);
#              ^~~~~~~~~~~~~
# helloList.h: In function ‘insert’:
# helloList.h:401:3: warning: implicit declaration of function ‘printMyLabels’ [-Wimplicit-function-declaration]
#    printMyLabels();
#    ^~~~~~~~~~~~~
# helloList.h: In function ‘delete’:
# helloList.h:724:6: warning: implicit declaration of function ‘notify_lostmychild’ [-Wimplicit-function-declaration]
#       notify_lostmychild(temp->port);
#       ^~~~~~~~~~~~~~~~~~
# helloList.h:754:8: warning: implicit declaration of function ‘deleteIPLabel’; did you mean ‘deleteStable’? [-Wimplicit-function-declaration]
#         deleteIPLabel(temp->port);
#         ^~~~~~~~~~~~~
#         deleteStable
# helloList.h: In function ‘deleteTag’:
# helloList.h:883:17: warning: comparison of distinct pointer types lacks a cast
#        if (fNode == headStable) {
#                  ^~
# helloList.h:885:19: warning: assignment to ‘struct stablePort *’ from incompatible pointer type ‘struct portTag *’ [-Wincompatible-pointer-types]
#         headStable = fNode->next;
#                    ^
# helloM_List.c: At top level:
# helloM_List.c:153:6: warning: conflicting types for ‘printMyLabels’
#  void printMyLabels();
#       ^~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h:401:3: note: previous implicit declaration of ‘printMyLabels’ was here
#    printMyLabels();
#    ^~~~~~~~~~~~~
# helloM_List.c: In function ‘_get_MACTest’:
# helloM_List.c:483:28: warning: passing argument 1 of ‘delete_failed_LL_Addr’ from incompatible pointer type [-Wincompatible-pointer-types]
#       delete_failed_LL_Addr(failedLL_head);
#                             ^~~~~~~~~~~~~
# In file included from helloList.h:20,
#                  from helloM_List.c:22:
# endNetworkUtils.h:50:28: note: expected ‘uint8_t *’ {aka ‘unsigned char *’} but argument is of type ‘struct addr_tuple *’
#  void delete_failed_LL_Addr(uint8_t* );
#                             ^~~~~~~~
# helloM_List.c: In function ‘sendNullJoin’:
# helloM_List.c:1219:35: warning: passing argument 2 of ‘ctrlLabelSend’ from incompatible pointer type [-Wincompatible-pointer-types]
#   ctrlLabelSend(MESSAGE_TYPE_JOIN, to_port, labelAssignmentPayLoad);
#                                    ^~~~~~~
# helloM_List.c:33:36: note: expected ‘char *’ but argument is of type ‘int *’
#  extern int ctrlLabelSend(int, char eth[], char pay[]);
#                                ~~~~~^~~~~
# helloM_List.c: At top level:
# helloM_List.c:1564:6: warning: conflicting types for ‘notify_lostmychild’
#  void notify_lostmychild(char port[20]) {
#       ^~~~~~~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h:724:6: note: previous implicit declaration of ‘notify_lostmychild’ was here
#       notify_lostmychild(temp->port);
#       ^~~~~~~~~~~~~~~~~~
# helloM_List.c:1668:6: warning: conflicting types for ‘notify_myLabels_Update’
#  void notify_myLabels_Update(int update_action, char inTier[20]) {
#       ^~~~~~~~~~~~~~~~~~~~~~
# In file included from helloList.h:19,
#                  from helloM_List.c:22:
# tierList.h:191:8: note: previous implicit declaration of ‘notify_myLabels_Update’ was here
#         notify_myLabels_Update(2,tempDel);
#         ^~~~~~~~~~~~~~~~~~~~~~
# helloM_List.c: In function ‘responseIPresolve’:
# helloM_List.c:1804:20: warning: implicit declaration of function ‘buildIPResolvePacket’ [-Wimplicit-function-declaration]
#    mplrPayloadLen = buildIPResolvePacket(mplrPayload, DestTierLabel, tierValue);
#                     ^~~~~~~~~~~~~~~~~~~~
# helloM_List.c: At top level:
# helloM_List.c:1844:6: warning: conflicting types for ‘deleteIPLabel’
#  void deleteIPLabel(char failedEth[]) {
#       ^~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h:754:8: note: previous implicit declaration of ‘deleteIPLabel’ was here
#         deleteIPLabel(temp->port);
#         ^~~~~~~~~~~~~
# helloM_List.c: In function ‘publishIPLabelMap’:
# helloM_List.c:1938:20: warning: implicit declaration of function ‘buildIPPublishPacket’ [-Wimplicit-function-declaration]
#    mplrPayloadLen = buildIPPublishPacket(mplrPayload, label);
#                     ^~~~~~~~~~~~~~~~~~~~
# helloM_List.c: In function ‘findParentofDestination’:
# helloM_List.c:1959:17: warning: implicit declaration of function ‘getParent’; did you mean ‘getservent’? [-Wimplicit-function-declaration]
#   parentofDest = getParent(DestTierLabel, '.');
#                  ^~~~~~~~~
#                  getservent
# helloM_List.c:1959:15: warning: assignment to ‘char *’ from ‘int’ makes pointer from integer without a cast [-Wint-conversion]
#   parentofDest = getParent(DestTierLabel, '.');
#                ^
# helloM_List.c: In function ‘hello_msg’:
# helloM_List.c:2110:17: warning: passing argument 1 of ‘sendNullJoin’ from incompatible pointer type [-Wincompatible-pointer-types]
#     sendNullJoin(recvOnEtherPort);
#                  ^~~~~~~~~~~~~~~
# helloM_List.c:1205:23: note: expected ‘int *’ but argument is of type ‘char *’
#  void sendNullJoin(int to_port[20]) {
#                    ~~~~^~~~~~~~~~~
# helloM_List.c:2122:18: warning: passing argument 1 of ‘sendNullJoin’ from incompatible pointer type [-Wincompatible-pointer-types]
#      sendNullJoin(recvOnEtherPort);
#                   ^~~~~~~~~~~~~~~
# helloM_List.c:1205:23: note: expected ‘int *’ but argument is of type ‘char *’
#  void sendNullJoin(int to_port[20]) {
#                    ~~~~^~~~~~~~~~~
# helloM_List.c: In function ‘msg_typ_labl_add’:
# helloM_List.c:2696:16: warning: passing argument 1 of ‘sendNullJoin’ from incompatible pointer type [-Wincompatible-pointer-types]
#    sendNullJoin(recvOnEtherPort);
#                 ^~~~~~~~~~~~~~~
# helloM_List.c:1205:23: note: expected ‘int *’ but argument is of type ‘char *’
#  void sendNullJoin(int to_port[20]) {
#                    ~~~~^~~~~~~~~~~
# helloM_List.c: In function ‘msg_typ_labl_delt’:
# helloM_List.c:2762:24: warning: passing argument 1 of ‘delete_failed_LL_Addr’ from incompatible pointer type [-Wincompatible-pointer-types]
#   delete_failed_LL_Addr(failedLL_head);
#                         ^~~~~~~~~~~~~
# In file included from helloList.h:20,
#                  from helloM_List.c:22:
# endNetworkUtils.h:50:28: note: expected ‘uint8_t *’ {aka ‘unsigned char *’} but argument is of type ‘struct addr_tuple *’
#  void delete_failed_LL_Addr(uint8_t* );
#                             ^~~~~~~~
# helloM_List.c: In function ‘msg_typ_rqst_ip’:
# helloM_List.c:2816:3: warning: implicit declaration of function ‘findIPforLabel’; did you mean ‘findPortName’? [-Wimplicit-function-declaration]
#    findIPforLabel(MytierAddrTemp, mylabelIP);
#    ^~~~~~~~~~~~~~
#    findPortName
# helloM_List.c: In function ‘msg_typ_ip_add’:
# helloM_List.c:3123:49: warning: implicit declaration of function ‘searchIPinMyMap’ [-Wimplicit-function-declaration]
#    if (strcmp(ip_add, inet_ntoa(ipAddr)) == 0 || searchIPinMyMap(inet_ntoa(ipAddr)) == 0) {
#                                                  ^~~~~~~~~~~~~~~
#
# Waiting for result from node a2
# stdout:
# stderr: endNW.c: In function ‘delete_entry_LL_Addr’:
# endNW.c:174:7: warning: implicit declaration of function ‘publishIPLabelMap’ [-Wimplicit-function-declaration]
#        publishIPLabelMap(current->tier_addr,1);
#        ^~~~~~~~~~~~~~~~~
# endNW.c: In function ‘updateEndTierAddr’:
# endNW.c:693:3: warning: implicit declaration of function ‘printAddresstoResponse’ [-Wimplicit-function-declaration]
#    printAddresstoResponse();
#    ^~~~~~~~~~~~~~~~~~~~~~
# endNW.c:733:3: warning: implicit declaration of function ‘requestIPresolve’ [-Wimplicit-function-declaration]
#    requestIPresolve(destinationInterfaceIPAddr,Mytier);
#    ^~~~~~~~~~~~~~~~
# In file included from helloList.h:19,
#                  from helloM_List.c:22:
# tierList.h: In function ‘deleteTierAddr’:
# tierList.h:191:8: warning: implicit declaration of function ‘notify_myLabels_Update’ [-Wimplicit-function-declaration]
#         notify_myLabels_Update(2,tempDel);
#         ^~~~~~~~~~~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h: In function ‘append’:
# helloList.h:90:19: warning: implicit declaration of function ‘matchPort’ [-Wimplicit-function-declaration]
#   int match_Port = matchPort(inPort);
#                    ^~~~~~~~~
# helloList.h:92:3: warning: implicit declaration of function ‘tagport’; did you mean ‘abort’? [-Wimplicit-function-declaration]
#    tagport(inPort,1);
#    ^~~~~~~
#    abort
# helloList.h: In function ‘staging’:
# helloList.h:340:24: warning: implicit declaration of function ‘findStable’; did you mean ‘findPortName’? [-Wimplicit-function-declaration]
#   int checkstableport = findStable(inPort);
#                         ^~~~~~~~~~
#                         findPortName
# helloList.h:345:22: warning: implicit declaration of function ‘findStaging’; did you mean ‘staging’? [-Wimplicit-function-declaration]
#    int checkStaging = findStaging(inPort);
#                       ^~~~~~~~~~~
#                       staging
# helloList.h:372:13: warning: implicit declaration of function ‘updateStaging’ [-Wimplicit-function-declaration]
#     stable = updateStaging(inPort);
#              ^~~~~~~~~~~~~
# helloList.h: In function ‘insert’:
# helloList.h:401:3: warning: implicit declaration of function ‘printMyLabels’ [-Wimplicit-function-declaration]
#    printMyLabels();
#    ^~~~~~~~~~~~~
# helloList.h: In function ‘delete’:
# helloList.h:724:6: warning: implicit declaration of function ‘notify_lostmychild’ [-Wimplicit-function-declaration]
#       notify_lostmychild(temp->port);
#       ^~~~~~~~~~~~~~~~~~
# helloList.h:754:8: warning: implicit declaration of function ‘deleteIPLabel’; did you mean ‘deleteStable’? [-Wimplicit-function-declaration]
#         deleteIPLabel(temp->port);
#         ^~~~~~~~~~~~~
#         deleteStable
# helloList.h: In function ‘deleteTag’:
# helloList.h:883:17: warning: comparison of distinct pointer types lacks a cast
#        if (fNode == headStable) {
#                  ^~
# helloList.h:885:19: warning: assignment to ‘struct stablePort *’ from incompatible pointer type ‘struct portTag *’ [-Wincompatible-pointer-types]
#         headStable = fNode->next;
#                    ^
# helloM_List.c: At top level:
# helloM_List.c:153:6: warning: conflicting types for ‘printMyLabels’
#  void printMyLabels();
#       ^~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h:401:3: note: previous implicit declaration of ‘printMyLabels’ was here
#    printMyLabels();
#    ^~~~~~~~~~~~~
# helloM_List.c: In function ‘_get_MACTest’:
# helloM_List.c:483:28: warning: passing argument 1 of ‘delete_failed_LL_Addr’ from incompatible pointer type [-Wincompatible-pointer-types]
#       delete_failed_LL_Addr(failedLL_head);
#                             ^~~~~~~~~~~~~
# In file included from helloList.h:20,
#                  from helloM_List.c:22:
# endNetworkUtils.h:50:28: note: expected ‘uint8_t *’ {aka ‘unsigned char *’} but argument is of type ‘struct addr_tuple *’
#  void delete_failed_LL_Addr(uint8_t* );
#                             ^~~~~~~~
# helloM_List.c: In function ‘sendNullJoin’:
# helloM_List.c:1219:35: warning: passing argument 2 of ‘ctrlLabelSend’ from incompatible pointer type [-Wincompatible-pointer-types]
#   ctrlLabelSend(MESSAGE_TYPE_JOIN, to_port, labelAssignmentPayLoad);
#                                    ^~~~~~~
# helloM_List.c:33:36: note: expected ‘char *’ but argument is of type ‘int *’
#  extern int ctrlLabelSend(int, char eth[], char pay[]);
#                                ~~~~~^~~~~
# helloM_List.c: At top level:
# helloM_List.c:1564:6: warning: conflicting types for ‘notify_lostmychild’
#  void notify_lostmychild(char port[20]) {
#       ^~~~~~~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h:724:6: note: previous implicit declaration of ‘notify_lostmychild’ was here
#       notify_lostmychild(temp->port);
#       ^~~~~~~~~~~~~~~~~~
# helloM_List.c:1668:6: warning: conflicting types for ‘notify_myLabels_Update’
#  void notify_myLabels_Update(int update_action, char inTier[20]) {
#       ^~~~~~~~~~~~~~~~~~~~~~
# In file included from helloList.h:19,
#                  from helloM_List.c:22:
# tierList.h:191:8: note: previous implicit declaration of ‘notify_myLabels_Update’ was here
#         notify_myLabels_Update(2,tempDel);
#         ^~~~~~~~~~~~~~~~~~~~~~
# helloM_List.c: In function ‘responseIPresolve’:
# helloM_List.c:1804:20: warning: implicit declaration of function ‘buildIPResolvePacket’ [-Wimplicit-function-declaration]
#    mplrPayloadLen = buildIPResolvePacket(mplrPayload, DestTierLabel, tierValue);
#                     ^~~~~~~~~~~~~~~~~~~~
# helloM_List.c: At top level:
# helloM_List.c:1844:6: warning: conflicting types for ‘deleteIPLabel’
#  void deleteIPLabel(char failedEth[]) {
#       ^~~~~~~~~~~~~
# In file included from helloM_List.c:22:
# helloList.h:754:8: note: previous implicit declaration of ‘deleteIPLabel’ was here
#         deleteIPLabel(temp->port);
#         ^~~~~~~~~~~~~
# helloM_List.c: In function ‘publishIPLabelMap’:
# helloM_List.c:1938:20: warning: implicit declaration of function ‘buildIPPublishPacket’ [-Wimplicit-function-declaration]
#    mplrPayloadLen = buildIPPublishPacket(mplrPayload, label);
#                     ^~~~~~~~~~~~~~~~~~~~
# helloM_List.c: In function ‘findParentofDestination’:
# helloM_List.c:1959:17: warning: implicit declaration of function ‘getParent’; did you mean ‘getservent’? [-Wimplicit-function-declaration]
#   parentofDest = getParent(DestTierLabel, '.');
#                  ^~~~~~~~~
#                  getservent
# helloM_List.c:1959:15: warning: assignment to ‘char *’ from ‘int’ makes pointer from integer without a cast [-Wint-conversion]
#   parentofDest = getParent(DestTierLabel, '.');
#                ^
# helloM_List.c: In function ‘hello_msg’:
# helloM_List.c:2110:17: warning: passing argument 1 of ‘sendNullJoin’ from incompatible pointer type [-Wincompatible-pointer-types]
#     sendNullJoin(recvOnEtherPort);
#                  ^~~~~~~~~~~~~~~
# helloM_List.c:1205:23: note: expected ‘int *’ but argument is of type ‘char *’
#  void sendNullJoin(int to_port[20]) {
#                    ~~~~^~~~~~~~~~~
# helloM_List.c:2122:18: warning: passing argument 1 of ‘sendNullJoin’ from incompatible pointer type [-Wincompatible-pointer-types]
#      sendNullJoin(recvOnEtherPort);
#                   ^~~~~~~~~~~~~~~
# helloM_List.c:1205:23: note: expected ‘int *’ but argument is of type ‘char *’
#  void sendNullJoin(int to_port[20]) {
#                    ~~~~^~~~~~~~~~~
# helloM_List.c: In function ‘msg_typ_labl_add’:
# helloM_List.c:2696:16: warning: passing argument 1 of ‘sendNullJoin’ from incompatible pointer type [-Wincompatible-pointer-types]
#    sendNullJoin(recvOnEtherPort);
#                 ^~~~~~~~~~~~~~~
# helloM_List.c:1205:23: note: expected ‘int *’ but argument is of type ‘char *’
#  void sendNullJoin(int to_port[20]) {
#                    ~~~~^~~~~~~~~~~
# helloM_List.c: In function ‘msg_typ_labl_delt’:
# helloM_List.c:2762:24: warning: passing argument 1 of ‘delete_failed_LL_Addr’ from incompatible pointer type [-Wincompatible-pointer-types]
#   delete_failed_LL_Addr(failedLL_head);
#                         ^~~~~~~~~~~~~
# In file included from helloList.h:20,
#                  from helloM_List.c:22:
# endNetworkUtils.h:50:28: note: expected ‘uint8_t *’ {aka ‘unsigned char *’} but argument is of type ‘struct addr_tuple *’
#  void delete_failed_LL_Addr(uint8_t* );
#                             ^~~~~~~~
# helloM_List.c: In function ‘msg_typ_rqst_ip’:
# helloM_List.c:2816:3: warning: implicit declaration of function ‘findIPforLabel’; did you mean ‘findPortName’? [-Wimplicit-function-declaration]
#    findIPforLabel(MytierAddrTemp, mylabelIP);
#    ^~~~~~~~~~~~~~
#    findPortName
# helloM_List.c: In function ‘msg_typ_ip_add’:
# helloM_List.c:3123:49: warning: implicit declaration of function ‘searchIPinMyMap’ [-Wimplicit-function-declaration]
#    if (strcmp(ip_add, inet_ntoa(ipAddr)) == 0 || searchIPinMyMap(inet_ntoa(ipAddr)) == 0) {
#                                                  ^~~~~~~~~~~~~~~

# %% [markdown]
# ## Reading command file and running MNLR code on each node using tmux
#
# This code reads a configuration file ('config.txt') with node names and associated commands, storing them in a dictionary. It then uses this data to create and execute new tmux sessions for each node with the specified command using a manager's function.

# %%
import time

# Open the .txt file for reading
with open('config_small.txt', 'r') as file:
    # Initialize an empty dictionary to store the configuration data
    config_data = {}
    
    # Loop through each line in the file
    for line in file:
        # Split the line by comma to separate the node name and command
        parts = line.strip().split(',')
        
        # Check if there are two parts (node name and command)
        if len(parts) == 2:
            node_name, command = parts
            config_data[node_name] = command

# Now you have a dictionary with node names as keys and commands as values
# You can access the data like this:
for node_name, command in config_data.items():
    print(f"Node: {node_name}, Command: {command}")
    
    startCmd = f"tmux new-session -d -s MNLR 'cd ~/MNLR_Code; {command}'"
    print (startCmd)
#tmux new-session -d -s name creates a new session, detaches it and gives it a name  
#f in python - provides data to a string - in our case is is {command}  
# in the new terminal run the command
    manager.executeCommandsParallel(startCmd, prefixList=node_name)
    time.sleep(5)
# Out:
# Node: c1, Command: sudo ./MNLR -T 1 -L 1.1 -N 1
# tmux new-session -d -s MNLR 'cd ~/MNLR_Code; sudo ./MNLR -T 1 -L 1.1 -N 1'
# Starting command on node c1
# Command to execute: tmux new-session -d -s MNLR 'cd ~/MNLR_Code; sudo ./MNLR -T 1 -L 1.1 -N 1'
# Waiting for result from node c1
# stdout:
# stderr:
# Node: d1, Command: sudo ./MNLR -T 2 -N 1
# tmux new-session -d -s MNLR 'cd ~/MNLR_Code; sudo ./MNLR -T 2 -N 1'
# Starting command on node d1
# Command to execute: tmux new-session -d -s MNLR 'cd ~/MNLR_Code; sudo ./MNLR -T 2 -N 1'
# Waiting for result from node d1
# stdout:
# stderr:
# Node: d2, Command: sudo ./MNLR -T 2 -N 1
# tmux new-session -d -s MNLR 'cd ~/MNLR_Code; sudo ./MNLR -T 2 -N 1'
# Starting command on node d2
# Command to execute: tmux new-session -d -s MNLR 'cd ~/MNLR_Code; sudo ./MNLR -T 2 -N 1'
# Waiting for result from node d2
# stdout:
# stderr:
# Node: a1, Command: sudo ./MNLR -T 3 -N 0 192.168.4.254 24 eth3
# tmux new-session -d -s MNLR 'cd ~/MNLR_Code; sudo ./MNLR -T 3 -N 0 192.168.4.254 24 eth3'
# Starting command on node a1
# Command to execute: tmux new-session -d -s MNLR 'cd ~/MNLR_Code; sudo ./MNLR -T 3 -N 0 192.168.4.254 24 eth3'
# Waiting for result from node a1
# stdout:
# stderr:
# Node: a2, Command: sudo ./MNLR -T 3 -N 0 192.168.5.254 24 eth3
# tmux new-session -d -s MNLR 'cd ~/MNLR_Code; sudo ./MNLR -T 3 -N 0 192.168.5.254 24 eth3'
# Starting command on node a2
# Command to execute: tmux new-session -d -s MNLR 'cd ~/MNLR_Code; sudo ./MNLR -T 3 -N 0 192.168.5.254 24 eth3'
# Waiting for result from node a2
# stdout:
# stderr:

# %% [markdown]
# ## WAIT FOR a MINUTE

# %% [markdown]
# ## KILL tmux session MNLR

# %%
stopCmd = "tmux kill-session -t MNLR"
manager.executeCommandsParallel(stopCmd, prefixList="a")
manager.executeCommandsParallel(stopCmd, prefixList="d")
manager.executeCommandsParallel(stopCmd, prefixList="c")
# Out:
# Starting command on node a1
# Command to execute: tmux kill-session -t MNLR
# Starting command on node a2
# Command to execute: tmux kill-session -t MNLR
# Waiting for result from node a1
# stdout:
# stderr:
# Waiting for result from node a2
# stdout:
# stderr:
# Starting command on node d1
# Command to execute: tmux kill-session -t MNLR
# Starting command on node d2
# Command to execute: tmux kill-session -t MNLR
# Waiting for result from node d1
# stdout:
# stderr:
# Waiting for result from node d2
# stdout:
# stderr:
# Starting command on node c1
# Command to execute: tmux kill-session -t MNLR
# Waiting for result from node c1
# stdout:
# stderr:

# %% [markdown]
# ## WAIT FEW MINUTES

# %% [markdown]
# ## Collect Log Results
#
# This code creates a directory for log files if it doesn't exist and then downloads log files named in the format "EIBP_{name}.log" from multiple destinations with prefixes "c," "d," and "a" into the specified log directory.It also adds the node name to the downloaded log files' names.
#
# Now that the nodes have logged updates to their respective log files, they need to be downloaded to be analyzed.

# %%
import os

LOG_DIR_PATH = "../logs"
LOG_NAME = "EIBP_{name}.log"
logPath = os.path.join(LOG_DIR_PATH, LOG_NAME)

# If the logs directory does not already exist, create it
if not os.path.exists(LOG_DIR_PATH):
    os.makedirs(LOG_DIR_PATH)
    
manager.downloadFilesParallel(logPath, LOG_NAME, prefixList="c,d,a", addNodeName=True)
# Out:
# Starting download on node c1
# File to download: EIBP_c1.log
# Location of download: ../logs/EIBP_c1.log
# Starting download on node d1
# File to download: EIBP_d1.log
# Location of download: ../logs/EIBP_d1.log
# Starting download on node d2
# File to download: EIBP_d2.log
# Location of download: ../logs/EIBP_d2.log
# Starting download on node a1
# File to download: EIBP_a1.log
# Location of download: ../logs/EIBP_a1.log
# Starting download on node a2
# File to download: EIBP_a2.log
# Location of download: ../logs/EIBP_a2.log
# Waiting for result from node c1
# Output: None
# Waiting for result from node d1
# Output: None
# Waiting for result from node d2
# Output: None
# Waiting for result from node a1
# Output: None
# Waiting for result from node a2
# Output: None

# %%
import os

DIR_PATH = "../pcap"
NAME = "c1_eth2.pcap"
Path = os.path.join(DIR_PATH, NAME)

# If the logs directory does not already exist, create it
if not os.path.exists(DIR_PATH):
    os.makedirs(DIR_PATH)
    
manager.downloadFilesParallel(Path,NAME, prefixList="c", addNodeName=True)

# %% [markdown]
# ## Delete the Log from a Prior Test (if required)
#
# This code is executing the command to remove log files with names starting with "EIBP_" for three nodes (prefixes): "c," "d," and "a," using a manager's function called "executeCommandsParallel."

# %%
rmLogCmd = "rm EIBP_*.log"
manager.executeCommandsParallel(rmLogCmd, prefixList="c,d,a")
